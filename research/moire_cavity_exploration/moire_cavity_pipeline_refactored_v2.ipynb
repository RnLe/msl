# %% [markdown]
# # Moiré Cavity Pipeline — Full Refactor (v2)
#
# This notebook follows the exact flow you described:
#
# 1) **Set parameters** manually for the best candidate (lattice + parameters, target band, target k-point).
# 2) **Compute monolayer band diagram** once, highlight the target band and target k-point.
# 3) **Construct a test moiré lattice** at 1.1° and **plot the stacking register**.
# 4) **Construct mini moiré unit cells** for AA/AB/BA with sizes of **1×, 2×, 3×** the moiré lattice constant(s); visualize.
# 5) **Compute band diagrams** (same polarization, 8 bands by default) **for all 9 cases** (3 registries × 3 sizes).
#    - For the moiré unit-cell band diagrams, **use the moiré lattice vectors from your Rust framework** (see TODO in code).
#    - All band plots highlight the target band.
#    - The 9 plots are saved individually and also collated into a **3×3 montage image** for convenience.
# 6) **Optimize the moiré angle** (bounded 1D) using a physically grounded score (registry contrast + envelope bound states).
#    - For the **best angle**, compute **AA/AB/BA band diagrams** again and highlight the target band.
#
# > **Note:** This notebook relies on your `moire_lattice_py` bindings for lattice/BZ utilities. Where API details are unknown, there are clear **TODO** markers to drop your existing calls.

# %%
import numpy as np
import math, os, io, warnings
from dataclasses import dataclass
from typing import Dict, Tuple, Optional, List

import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from PIL import Image

# IMPORTANT: matplotlib rules for this environment
# - use matplotlib (no seaborn)
# - one chart per figure (no subplots)
# - do not set explicit colors unless asked; we rely on defaults

try:
    import meep as mp
    from meep import mpb
    MEEP_AVAILABLE = True
except Exception:
    MEEP_AVAILABLE = False

try:
    import moire_lattice_py as ml
    ML_AVAILABLE = True
except Exception:
    ML_AVAILABLE = False

print("Meep/MPB available:", MEEP_AVAILABLE)
print("moire_lattice_py available:", ML_AVAILABLE)
# Out:
# Using MPI version 4.1, 1 processes
# Meep/MPB available: True
# moire_lattice_py available: True

# %% [markdown]
# ## 1) Set candidate parameters

# %%
@dataclass
class Candidate:
    lattice_type: str   # 'triangular' | 'square' | 'rectangular' | 'oblique'
    a1: np.ndarray      # real-space basis vector 1
    a2: np.ndarray      # real-space basis vector 2
    hole_radius_a: float
    eps_bg: float
    polarization: str   # 'TE' or 'TM'
    band_index: int     # 0-based
    k_label: str        # e.g., 'Γ', 'X', 'M', 'K', ''

# ==== USER INPUTS ====
cand = Candidate(
    lattice_type="square",
    a1=np.array([1.0, 0.0]),
    a2=np.array([0.0, 1.0]),
    hole_radius_a=0.43,
    eps_bg=4.02,
    polarization="TM",
    band_index=3,
    k_label="M"
)

num_bands = 8           # how many bands to compute/plot
resolution = 40         # MPB resolution (pixels/a)
kpts_per_seg = 18       # points per segment on HS path
output_dir = "moire_pipeline_outputs"
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# ## Utilities: lattice builders and high-symmetry paths

# %%
def rotation_matrix(theta_deg: float) -> np.ndarray:
    th = math.radians(theta_deg)
    return np.array([[math.cos(th), -math.sin(th)],
                     [math.sin(th),  math.cos(th)]], dtype=float)

def lattice_matrix(a1: np.ndarray, a2: np.ndarray) -> np.ndarray:
    A = np.zeros((2,2), dtype=float); A[:,0] = a1; A[:,1] = a2
    return A

def mp_lattice_from_vectors(a1: np.ndarray, a2: np.ndarray):
    return mp.Lattice(size=mp.Vector3(1,1,0),
                      basis1=mp.Vector3(float(a1[0]), float(a1[1]), 0),
                      basis2=mp.Vector3(float(a2[0]), float(a2[1]), 0))

def hs_path_for_lattice(lattice_type: str, k_points_per_segment: int):
    lt = lattice_type.lower()
    labels = []
    label_inds = []

    def add_segment(p_from, p_to, lbl_from, lbl_to, pts):
        seg = mp.interpolate(k_points_per_segment, [p_from, p_to])
        if len(pts) > 0: seg = seg[1:]
        start_idx = len(pts)
        pts += seg
        if lbl_from is not None:
            if len(labels) == 0:
                labels.append(lbl_from); label_inds.append(start_idx)
        labels.append(lbl_to); label_inds.append(len(pts)-1)
        return pts

    pts = []
    if lt == "triangular":
        G = mp.Vector3(0,0); M = mp.Vector3(0.5,0.0); K = mp.Vector3(1/3,1/3)
        pts = add_segment(G,M,"Γ","M",pts)
        pts = add_segment(M,K,"M","K",pts)
        pts = add_segment(K,G,"K","Γ",pts)
    elif lt in ("square","rectangular"):
        G = mp.Vector3(0,0); X = mp.Vector3(0.5,0.0); M = mp.Vector3(0.5,0.5)
        pts = add_segment(G,X,"Γ","X",pts)
        pts = add_segment(X,M,"X","M",pts)
        pts = add_segment(M,G,"M","Γ",pts)
    else:
        # Oblique path (placeholder). For thorough oblique analysis, use BZ mesh in your other script.
        G = mp.Vector3(0,0); B1 = mp.Vector3(0.5,0.0); B2 = mp.Vector3(0.0,0.5)
        pts = add_segment(G,B1,"Γ","b1/2",pts)
        pts = add_segment(B1,B2,"b1/2","b2/2",pts)
        pts = add_segment(B2,G,"b2/2","Γ",pts)
    return pts, labels, label_inds

def path_arclength(kpts):
    ks = np.array([[kp.x, kp.y] for kp in kpts], dtype=float)
    if len(ks) < 2: return np.zeros(len(ks))
    ds = np.linalg.norm(np.diff(ks, axis=0), axis=1)
    return np.concatenate([[0.0], np.cumsum(ds)])

# %% [markdown]
# ## MPB helpers and plotting

# %%
# Plotting helper for band diagrams used in step 5

def plot_band_diagram(result: dict, lattice_type: str, target_band: int, k_label: str, outfile: str, title_prefix: str = ""):
    import matplotlib.pyplot as plt
    s = result["s"]
    # Choose which frequency array to plot
    freqs = result.get("freqs")
    if freqs is None:
        freqs = result.get("freqs_tm")
    if freqs is None:
        freqs = result.get("freqs_te")
    if freqs is None:
        raise ValueError("No frequency data found in result (expected 'freqs' or 'freqs_tm'/'freqs_te').")

    k_labels = result.get("k_labels", [])
    k_inds = result.get("k_inds", [])

    plt.figure(figsize=(6, 4))
    # Plot all bands
    nbands = freqs.shape[1] if freqs.ndim == 2 else len(freqs)
    if freqs.ndim == 2:
        for b in range(nbands):
            lw = 2.5 if b == target_band else 1.2
            alpha = 1.0 if b == target_band else 0.9
            plt.plot(s, freqs[:, b], linewidth=lw, alpha=alpha, color=(0.1, 0.1, 0.1))
    else:
        lw = 2.5 if 0 == target_band else 1.2
        plt.plot(s, freqs, linewidth=lw)

    # High-symmetry ticks and guides
    if len(k_inds) == len(k_labels) and len(k_inds) > 0:
        for xi in k_inds:
            plt.axvline(s[xi], color="0.8", linewidth=0.8)
        plt.xticks([s[i] for i in k_inds], k_labels)
    plt.xlabel("k-path")
    plt.ylabel("Frequency (c/a)")
    ttl = f"{title_prefix} bands ({lattice_type})"
    if k_label:
        ttl += f" — target: {k_label}"
    plt.title(ttl)
    plt.grid(True, alpha=0.2)
    plt.tight_layout()
    plt.savefig(outfile, dpi=160)
    plt.close()

# %%
# Geometry builder using reciprocal-based basis

def mpb_geometry_for_factor(L1_py, L2_py, factor: int, radius: float, eps_high: float, eps_low: float):
    import meep as mp
    # L1 real-space lattice vectors for MPB lattice
    (a1, a2) = L1_py.lattice_vectors()
    lat = mp.Lattice(size=mp.Vector3(1, 1), basis1=mp.Vector3(a1[0], a1[1]), basis2=mp.Vector3(a2[0], a2[1]))
    # Compute basis in fractional coordinates of L1 from reciprocal strays
    basis_frac = mpb_basis_from_reciprocal_strays(L1_py, L2_py, factor)
    # Build geometry: one high-index cylinder at each basis site
    geometry = []
    for (u, v) in basis_frac:
        center = mp.Vector3(u, v)
        geometry.append(mp.Cylinder(radius=radius, material=mp.Medium(epsilon=eps_high), center=center, axis=mp.Vector3(0, 0, 1)))
    default_material = mp.Medium(epsilon=eps_low)
    return lat, geometry, default_material, basis_frac

# %% [markdown]
# ## 2) Monolayer band diagram

# %%
# Reciprocal-space helpers
import numpy as np
from typing import List, Tuple, Optional


def reciprocal_rectangle_for_lattice(lattice_py, factor: int = 1) -> Tuple[float, float]:
    """
    Build an axis-aligned rectangle in reciprocal space whose area equals
    (factor * area of L1's reciprocal unit cell). We choose a square of side sqrt(area).
    Returns (width, height).
    """
    (g1, g2) = lattice_py.reciprocal_vectors()  # ((gx1, gy1), (gx2, gy2))
    g1 = np.array(g1)
    g2 = np.array(g2)
    # Parallelogram area = |G1 x G2|
    area = abs(g1[0]*g2[1] - g1[1]*g2[0])
    rect_area = max(1e-16, factor * float(area))
    side = float(np.sqrt(rect_area))
    width = side
    height = side
    return width, height


def fold_into_reciprocal_cell(L1_py, kx: float, ky: float) -> Tuple[float, float]:
    """
    Reduce a k-point into L1's first Brillouin zone using the lattice API if available,
    else fold by solving fractional coords in reciprocal basis and wrapping to [-0.5, 0.5).
    """
    try:
        rx, ry, _ = L1_py.reduce_to_brillouin_zone(kx, ky)
        return rx, ry
    except Exception:
        # Fallback folding using reciprocal basis
        (G1, G2) = L1_py.reciprocal_vectors()
        B = np.column_stack([G1, G2])  # 2x2
        frac = np.linalg.solve(B, np.array([kx, ky]))
        frac_wrapped = frac - np.round(frac)
        cart = B @ frac_wrapped
        return float(cart[0]), float(cart[1])


def reciprocal_stray_points(L1_py, L2_py, factor: int = 1) -> List[Tuple[float, float]]:
    """
    Get reciprocal lattice points of L2 within a rectangle whose area matches
    factor × (area of L1 reciprocal cell), fold into L1's 1st BZ. Return unique
    folded points excluding Γ (0,0).
    """
    width, height = reciprocal_rectangle_for_lattice(L1_py, factor)
    pts = L2_py.get_reciprocal_lattice_points_in_rectangle(width, height)
    folded = []
    for (kx, ky, _) in pts:
        rx, ry = fold_into_reciprocal_cell(L1_py, kx, ky)
        if abs(rx) < 1e-12 and abs(ry) < 1e-12:
            continue  # skip Gamma
        folded.append((rx, ry))
    # Uniquify with a tolerance
    uniq = []
    tol = 1e-9
    for p in folded:
        if not any((abs(p[0]-q[0]) < tol and abs(p[1]-q[1]) < tol) for q in uniq):
            uniq.append(p)
    return uniq


def mpb_basis_from_reciprocal_strays(
    L1_py,
    L2_py,
    factor: int = 1,
    include_all_strays: bool = False,
    max_additional: Optional[int] = None,
    min_frac_sep: float = 0.0,
) -> List[Tuple[float, float]]:
    """
    Map reciprocal stray points to a real-space fractional basis for MPB.
    - Always include the L1 site at (0,0).
    - Selection policy:
        * include_all_strays=True  -> add all stray-derived sites
        * else if max_additional   -> cap extras to max_additional
        * else                     -> soft cap at max(1, factor)
    - min_frac_sep: prune added sites with a minimal torus separation in fractional coords.
    """
    strays = reciprocal_stray_points(L1_py, L2_py, factor)
    basis = [(0.0, 0.0)]
    if not strays:
        return basis

    def k_to_frac(kx, ky) -> Tuple[float, float]:
        (G1, G2) = L1_py.reciprocal_vectors()
        B = np.column_stack([G1, G2])
        frac = np.linalg.solve(B, np.array([kx, ky]))  # reciprocal fractional coords
        # Use fractional coords directly and wrap to [0,1)
        u = float(frac[0] % 1.0)
        v = float(frac[1] % 1.0)
        return u, v

    # Decide how many to include
    if include_all_strays:
        picked = strays
    else:
        soft_cap = max(1, factor)
        cap = max_additional if (max_additional is not None) else soft_cap
        picked = strays[: min(len(strays), cap)]

    # Map to fractional coords and apply minimal separation pruning on torus
    def torus_dist(p, q):
        du = abs(p[0] - q[0])
        dv = abs(p[1] - q[1])
        du = min(du, 1.0 - du)
        dv = min(dv, 1.0 - dv)
        return np.hypot(du, dv)

    added: List[Tuple[float, float]] = []
    for kx, ky in picked:
        u, v = k_to_frac(kx, ky)
        if min_frac_sep > 0.0:
            if any(torus_dist((u, v), q) < min_frac_sep for q in added):
                continue
        added.append((u, v))

    basis.extend(added)
    return basis


def plot_reciprocal_registry(L1_py, L2_py, factor: int = 1, ax=None):
    import matplotlib.pyplot as plt
    if ax is None:
        fig, ax = plt.subplots(figsize=(4, 4))
    # Draw rectangle (area-matched) for visualization
    width, height = reciprocal_rectangle_for_lattice(L1_py, factor)
    ax.add_patch(plt.Rectangle((-width/2, -height/2), width, height, fill=False, ls='--', lw=1.0, color='gray'))
    # Plot L2 reciprocal points in the rectangle
    pts = L2_py.get_reciprocal_lattice_points_in_rectangle(width, height)
    if pts:
        xs = [p[0] for p in pts]
        ys = [p[1] for p in pts]
        ax.scatter(xs, ys, s=8, c='tab:blue', alpha=0.5, label='L2 G-points')
    # Plot folded stray points
    strays = reciprocal_stray_points(L1_py, L2_py, factor)
    if strays:
        ax.scatter([p[0] for p in strays], [p[1] for p in strays], s=30, c='tab:red', label='Folded strays')
    ax.scatter([0.0], [0.0], c='k', s=20, label='Γ')
    ax.set_aspect('equal', adjustable='box')
    ax.legend(loc='upper right', fontsize=8)
    ax.set_title(f"Reciprocal registry (factor={factor})")
    return ax

# %% [markdown]
# ## 3) Test moiré lattice at 1.1° and stacking register plot

# %%
theta_test_deg = 3

def plot_stacking_register(a1: np.ndarray, a2: np.ndarray, theta_deg: float, outfile: str):
    # Create base lattice using moire_lattice_py framework
    if not ML_AVAILABLE:
        print("Warning: moire_lattice_py not available, using placeholder visualization")
        # Fallback to placeholder
        A = np.stack([a1, a2], axis=1)
        R = rotation_matrix(theta_deg)
        B = R @ A
        # sample a small set of lattice points
        def pts(a1,a2,rad=3):
            P = []
            for m in range(-rad,rad+1):
                for n in range(-rad,rad+1):
                    P.append(m*a1 + n*a2)
            return np.array(P)
        P1 = pts(a1,a2,30); P2 = pts(B[:,0],B[:,1],30)
        plt.figure(figsize=(6,6))
        plt.scatter(P1[:,0], P1[:,1], s=10)  # layer 1
        plt.scatter(P2[:,0], P2[:,1], s=10)  # layer 2
        plt.gca().set_aspect("equal","box")
        plt.title(f"Stacking register (heuristic view) @ {theta_deg:.2f}°")
        plt.tight_layout(); plt.savefig(outfile, dpi=140); plt.close()
        return
    
    # Create square lattice (assuming unit cell with a=1.0)
    lattice = ml.create_square_lattice(1.0)
    
    # Create moiré lattice at the specified angle
    moire = ml.py_twisted_bilayer(lattice, math.radians(theta_deg))
    
    # Get moiré lattice vectors
    (L1, L2) = moire.primitive_vectors()
    L1 = np.array([L1[0], L1[1]])  # convert to 2D
    L2 = np.array([L2[0], L2[1]])
    
    # Sample lattice points for both layers
    def generate_lattice_points(a1, a2, radius=30):
        points = []
        for m in range(-radius, radius+1):
            for n in range(-radius, radius+1):
                point = m*a1 + n*a2
                points.append(point)
        return np.array(points)
    
    # Layer 1 points (original lattice)
    P1 = generate_lattice_points(a1, a2, 30)
    
    # Layer 2 points (rotated lattice)  
    R = rotation_matrix(theta_deg)
    a1_rot = R @ a1
    a2_rot = R @ a2
    P2 = generate_lattice_points(a1_rot, a2_rot, 30)
    
    # Create the plot
    plt.figure(figsize=(8,8))
    
    # Plot both lattices
    plt.scatter(P1[:,0], P1[:,1], s=20, alpha=0.6, label="Layer 1")
    plt.scatter(P2[:,0], P2[:,1], s=20, alpha=0.6, label="Layer 2")
    
    # Sample points within moiré unit cell to identify stacking
    n_sample = 20
    xs = np.linspace(0, 1, n_sample)
    ys = np.linspace(0, 1, n_sample)
    
    AA_points = []
    AB_points = []
    BA_points = []
    
    for i, x in enumerate(xs):
        for j, y in enumerate(ys):
            # Position in real space
            pos = x * L1 + y * L2
            pos_3d = [pos[0], pos[1], 0.0]
            
            # Check stacking type using the moiré framework
            stacking = moire.get_stacking_at(pos_3d)
            
            # For square lattice: AA at lattice points, AB/BA at half-lattice points
            # Use simple geometric approach for square lattice
            frac1 = np.array([x, y])  # fractional coordinates in moiré cell
            
            # Check proximity to AA sites (lattice points)
            dist_to_lattice = min(
                np.linalg.norm(frac1 - np.array([0, 0])),
                np.linalg.norm(frac1 - np.array([1, 0])),
                np.linalg.norm(frac1 - np.array([0, 1])),
                np.linalg.norm(frac1 - np.array([1, 1]))
            )
            
            # Check proximity to AB sites (1/2, 0) and (0, 1/2) type points
            dist_to_AB = min(
                np.linalg.norm(frac1 - np.array([0.5, 0])),
                np.linalg.norm(frac1 - np.array([0, 0.5])),
                np.linalg.norm(frac1 - np.array([0.5, 1])),
                np.linalg.norm(frac1 - np.array([1, 0.5]))
            )
            
            # Check proximity to BA sites (1/2, 1/2) type points  
            dist_to_BA = np.linalg.norm(frac1 - np.array([0.5, 0.5]))
            
            tol = 0.15  # tolerance for classification
            if dist_to_lattice < tol:
                AA_points.append(pos)
            elif dist_to_AB < tol:
                AB_points.append(pos)
            elif dist_to_BA < tol:
                BA_points.append(pos)
    
    # Plot stacking regions
    if AA_points:
        AA_points = np.array(AA_points)
        plt.scatter(AA_points[:,0], AA_points[:,1], s=100, c='red', marker='s', 
                   alpha=0.8, label='AA stacking')
    if AB_points:
        AB_points = np.array(AB_points)
        plt.scatter(AB_points[:,0], AB_points[:,1], s=100, c='blue', marker='^', 
                   alpha=0.8, label='AB stacking')
    if BA_points:
        BA_points = np.array(BA_points)
        plt.scatter(BA_points[:,0], BA_points[:,1], s=100, c='green', marker='v', 
                   alpha=0.8, label='BA stacking')
    
    # Outline the moiré unit cell
    moire_cell = np.array([[0,0], L1, L1+L2, L2, [0,0]])
    plt.plot(moire_cell[:,0], moire_cell[:,1], 'k-', linewidth=3, alpha=0.8, 
            label='Moiré unit cell')
    
    plt.gca().set_aspect("equal","box")
    plt.legend()
    plt.title(f"Stacking register @ {theta_deg:.2f}° (Moiré period ≈ {np.linalg.norm(L1):.1f})")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.tight_layout()
    plt.savefig(outfile, dpi=140)
    plt.close()

stack_plot = os.path.join(output_dir, "02_stacking_register_test_angle.png")
plot_stacking_register(cand.a1, cand.a2, theta_test_deg, stack_plot)
stack_plot
# Out:
# 'moire_pipeline_outputs/02_stacking_register_test_angle.png'

# %% [markdown]
# ## 4) Mini moiré unit cells (AA/AB/BA) with sizes 1×, 2×, 3×

# %%
def compute_moire_cell_approx(a1: np.ndarray, a2: np.ndarray, theta_deg: float,
                              Nmax: int = 60, tol: float = 1e-6):
    # Integer search approximant for commensurate moiré vectors (fallback if API not available).
    A = np.stack([a1,a2],axis=1)
    R = rotation_matrix(theta_deg); B = R @ A
    best = None; best_err = 1e9
    for m1 in range(-Nmax, Nmax+1):
        for m2 in range(-Nmax, Nmax+1):
            if m1==0 and m2==0: continue
            u = A @ np.array([m1,m2],float)
            for n1 in range(-Nmax, Nmax+1):
                for n2 in range(-Nmax, Nmax+1):
                    if n1==0 and n2==0: continue
                    v = B @ np.array([n1,n2],float)
                    e = np.linalg.norm(u-v)
                    if e < best_err:
                        best_err = e; best = (u,v)
                        if e < tol: break
                if best_err<tol: break
            if best_err<tol: break
        if best_err<tol: break
    if best is None: raise RuntimeError("Failed to find commensurate approximant.")
    # pick u as L1; find L2 by a secondary search encouraging independence
    L1 = best[0]
    best2 = None; best2_err = 1e9
    for m1 in range(-Nmax, Nmax+1):
        for m2 in range(-Nmax, Nmax+1):
            if m1==0 and m2==0: continue
            U = A @ np.array([m1,m2],float)
            # favor non-collinearity
            cross = abs(np.cross([U[0],U[1],0],[L1[0],L1[1],0])[-1])
            if cross < 1e-6: continue
            for n1 in range(-Nmax, Nmax+1):
                for n2 in range(-Nmax, Nmax+1):
                    if n1==0 and n2==0: continue
                    V = B @ np.array([n1,n2],float)
                    e = np.linalg.norm(U - V)
                    if e < best2_err:
                        best2_err = e; best2 = U
    L2 = best2
    return L1, L2

def get_moire_vectors_from_framework(a1: np.ndarray, a2: np.ndarray, theta_deg: float):
    # Use the moire_lattice_py framework to get moiré lattice vectors
    if not ML_AVAILABLE:
        print("Warning: moire_lattice_py not available, using fallback approximation")
        return compute_moire_cell_approx(a1, a2, theta_deg)
    
    # Create base lattice - assume square lattice with unit parameter
    lattice = ml.create_square_lattice(1.0)
    
    # Create moiré lattice at the specified angle
    moire = ml.py_twisted_bilayer(lattice, math.radians(theta_deg))
    
    # Get the moiré lattice primitive vectors 
    (L1_3d, L2_3d) = moire.primitive_vectors()
    
    # Convert to 2D numpy arrays
    L1 = np.array([L1_3d[0], L1_3d[1]], dtype=float)
    L2 = np.array([L2_3d[0], L2_3d[1]], dtype=float)
    
    return L1, L2

def scaled_moire_vectors(L1: np.ndarray, L2: np.ndarray, scale: int):
    return (scale*L1, scale*L2)

def registry_basis_fractional(registry: str):
    """Return two fractional basis positions (u,v) for the given registry.
    For square lattices:
      - AA: (0,0) and (0,0)
      - AB: (0,0) and (0.5, 0.5)
      - BA: (0,0) and (0.5, -0.5)  (wrapped later)
    """
    if registry == "AA":
        return [(0.0, 0.0), (0.0, 0.0)]
    elif registry == "AB":
        return [(0.0, 0.0), (0.5, 0.5)]
    elif registry == "BA":
        return [(0.0, 0.0), (0.5, -0.5)]
    else:
        raise ValueError(f"Unknown registry: {registry}")

def frac_to_cart(a1: np.ndarray, a2: np.ndarray, u: float, v: float) -> np.ndarray:
    return u * a1 + v * a2

def wrap01(x: float) -> float:
    y = x % 1.0
    return y if y >= 0 else y + 1.0

def plot_moire_unit_cell(a1: np.ndarray, a2: np.ndarray, registry: str, theta_deg: float, outfile: str, title: str):
    """Plot moiré unit cell with two-point basis and one surrounding shell.
    Also overlay monolayer lattice points (layer 1 and rotated layer 2) clipped to the cell.
    """
    plt.figure(figsize=(8,8))

    # Draw central cell outline
    cell = np.array([[0,0], a1, a1+a2, a2, [0,0]], float)
    plt.plot(cell[:,0], cell[:,1], 'k-', linewidth=2.0, label='Moiré unit cell')

    # Draw one surrounding shell of cell outlines
    for m in (-1,0,1):
        for n in (-1,0,1):
            if m == 0 and n == 0:
                continue
            t = m*a1 + n*a2
            shell = cell + t
            plt.plot(shell[:,0], shell[:,1], color='gray', alpha=0.25, linewidth=1.0)

    # Basis fractional positions (wrap BA entry into [0,1))
    basis_frac_raw = registry_basis_fractional(registry)
    basis_frac = [(wrap01(u), wrap01(v)) for (u,v) in basis_frac_raw]
    basis_cart = [frac_to_cart(a1, a2, u, v) for (u,v) in basis_frac]

    # Overlay monolayer lattice points from framework within a bounding rectangle
    if ML_AVAILABLE:
        lattice = ml.create_square_lattice(1.0)
        # Bounding rectangle of central cell
        xmin, xmax = cell[:,0].min(), cell[:,0].max()
        ymin, ymax = cell[:,1].min(), cell[:,1].max()
        width = (xmax - xmin) * 1.2
        height = (ymax - ymin) * 1.2
        pts1 = lattice.get_direct_lattice_points_in_rectangle(width, height)
        P1 = np.array([[p[0], p[1]] for p in pts1])
        # Rotate layer 2 by twist angle and translate by registry offset
        R = rotation_matrix(theta_deg)
        P2 = (P1 @ R.T)
        # Registry translation for layer 2
        (u2, v2) = basis_frac[1]
        t2 = frac_to_cart(a1, a2, u2, v2)
        P2 = P2 + t2

        # Point-in-cell test (central cell only)
        def in_cell(pt: np.ndarray) -> bool:
            # Solve for u,v in pt = u*a1 + v*a2
            det = a1[0]*a2[1] - a1[1]*a2[0]
            if abs(det) < 1e-12:
                return False
            u = (pt[0]*a2[1] - pt[1]*a2[0]) / det
            v = (a1[0]*pt[1] - a1[1]*pt[0]) / det
            return (0.0 <= u <= 1.0) and (0.0 <= v <= 1.0)

        L1_in = np.array([p for p in P1 if in_cell(p)])
        L2_in = np.array([p for p in P2 if in_cell(p)])

        if len(L1_in) > 0:
            plt.scatter(L1_in[:,0], L1_in[:,1], s=30, c='tab:red', alpha=0.65, marker='o', label='Layer 1 lattice')
        if len(L2_in) > 0:
            plt.scatter(L2_in[:,0], L2_in[:,1], s=30, c='tab:blue', alpha=0.65, marker='s', label='Layer 2 lattice')

    # Plot basis markers (central cell)
    plt.scatter(basis_cart[0][0], basis_cart[0][1], s=160, c='tab:red', marker='o', edgecolors='k', linewidths=1.0, label='Basis 1 (A)')
    plt.scatter(basis_cart[1][0], basis_cart[1][1], s=160, c='tab:blue', marker='s', edgecolors='k', linewidths=1.0, label='Basis 2 (B)')

    # Axes settings
    plt.gca().set_aspect('equal', 'box')
    pad = 0.15 * max(np.linalg.norm(a1), np.linalg.norm(a2))
    xmin, xmax = cell[:,0].min()-pad, cell[:,0].max()+pad
    ymin, ymax = cell[:,1].min()-pad, cell[:,1].max()+pad
    plt.xlim(xmin, xmax); plt.ylim(ymin, ymax)

    plt.title(title)
    plt.xlabel('x'); plt.ylabel('y')
    plt.legend(loc='best', framealpha=0.85)
    plt.grid(True, alpha=0.25)
    plt.tight_layout()
    plt.savefig(outfile, dpi=160)
    plt.close()

L1, L2 = get_moire_vectors_from_framework(cand.a1, cand.a2, theta_test_deg)
unit_sizes = [1,2,3]
cell_imgs = []
for reg in ["AA","AB","BA"]:
    for sc in unit_sizes:
        l1,l2 = scaled_moire_vectors(L1,L2,sc)
        img_path = os.path.join(output_dir, f"03_cell_{reg}_{sc}x.png")
        plot_moire_unit_cell(l1, l2, reg, theta_test_deg, img_path, f"{reg} moiré cell — {sc}×")
        cell_imgs.append(img_path)
cell_imgs
# Out:
# ['moire_pipeline_outputs/03_cell_AA_1x.png',
#  'moire_pipeline_outputs/03_cell_AA_2x.png',
#  'moire_pipeline_outputs/03_cell_AA_3x.png',
#  'moire_pipeline_outputs/03_cell_AB_1x.png',
#  'moire_pipeline_outputs/03_cell_AB_2x.png',
#  'moire_pipeline_outputs/03_cell_AB_3x.png',
#  'moire_pipeline_outputs/03_cell_BA_1x.png',
#  'moire_pipeline_outputs/03_cell_BA_2x.png',
#  'moire_pipeline_outputs/03_cell_BA_3x.png']

# %% [markdown]
# ## 5) Band diagrams for 3 registries × 3 sizes (9 total)

# %%
def mpb_geometry_for_registry(registry: str, a1: np.ndarray, a2: np.ndarray,
                              hole_radius_a: float, eps_bg: float):
    # Two-point basis per unit cell from stacking:
    # AA: (0,0) + (0,0)
    # AB: (0,0) + (0.5, 0.5)
    # BA: (0,0) + (0.5, -0.5) wrapped to [0,1)
    def wrap01(x: float) -> float:
        y = x % 1.0
        return y if y >= 0 else y + 1.0

    if registry == "AA":
        basis_uv = [(0.0, 0.0), (0.0, 0.0)]
    elif registry == "AB":
        basis_uv = [(0.0, 0.0), (0.5, 0.5)]
    elif registry == "BA":
        basis_uv = [(0.0, 0.0), (wrap01(0.5), wrap01(-0.5))]
    else:
        raise ValueError(f"Unknown registry: {registry}")

    lat = mp_lattice_from_vectors(a1, a2)

    # Build geometry: two air cylinders per unit cell placed at fractional centers
    geom: List[mp.GeometricObject] = []
    for (u, v) in basis_uv:
        center_frac = mp.Vector3(u, v, 0)
        geom.append(mp.Cylinder(radius=hole_radius_a, material=mp.air, center=center_frac))

    mat = mp.Medium(epsilon=eps_bg)
    return lat, geom, mat

def run_bands_for_cell(registry: str, l1: np.ndarray, l2: np.ndarray,
                       lattice_type: str, target_band: int, k_label: str,
                       out_prefix: str):
    lat, geom, mat = mpb_geometry_for_registry(registry, l1, l2, cand.hole_radius_a, cand.eps_bg)
    kpts, k_labels, k_inds = hs_path_for_lattice(lattice_type, kpts_per_seg)
    ms = mpb.ModeSolver(geometry_lattice=lat, geometry=geom, default_material=mat,
                        k_points=kpts, resolution=resolution, num_bands=num_bands, dimensions=2)
    pol = cand.polarization.strip().lower()
    result = {}
    if pol == "tm":
        ms.run_tm(); result["freqs"] = np.array(ms.all_freqs)
    elif pol == "te":
        ms.run_te(); result["freqs"] = np.array(ms.all_freqs)
    else:
        ms.run_tm(); result["freqs_tm"] = np.array(ms.all_freqs)
        ms.reset_meep(); ms = mpb.ModeSolver(geometry_lattice=lat, geometry=geom, default_material=mat,
                                             k_points=kpts, resolution=resolution, num_bands=num_bands, dimensions=2)
        ms.run_te(); result["freqs_te"] = np.array(ms.all_freqs)
    result.update(dict(s=path_arclength(kpts), k_labels=k_labels, k_inds=np.array(k_inds)))
    outf = f"{out_prefix}.png"
    plot_band_diagram(result, lattice_type, target_band, k_label, outf,
                      title_prefix=f"Moiré {registry}")
    return outf

moire_band_plots = []
for reg in ["AA","AB","BA"]:
    for sc in unit_sizes:
        l1,l2 = scaled_moire_vectors(L1,L2,sc)
        outp = os.path.join(output_dir, f"04_bands_{reg}_{sc}x")
        png = run_bands_for_cell(reg, l1, l2, cand.lattice_type, cand.band_index, cand.k_label, outp)
        moire_band_plots.append(png)
moire_band_plots
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 40 x 40 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (-0.0261769, 0.999657, 0)
#      (-0.999657, -0.0261769, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (-0.0261769, 0.999657, 0)
#      (-0.999657, -0.0261769, 0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 58 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.02631578947368421, 0.0, 0.0>
#   Vector3<0.05263157894736842, 0.0, 0.0>
#   Vector3<0.07894736842105263, 0.0, 0.0>
#   Vector3<0.10526315789473684, 0.0, 0.0>
#   Vector3<0.13157894736842105, 0.0, 0.0>
#   Vector3<0.15789473684210525, 0.0, 0.0>
#   Vector3<0.18421052631578946, 0.0, 0.0>
#   Vector3<0.21052631578947367, 0.0, 0.0>
#   Vector3<0.23684210526315788, 0.0, 0.0>
#   Vector3<0.2631578947368421, 0.0, 0.0>
#   Vector3<0.2894736842105263, 0.0, 0.0>
#   Vector3<0.3157894736842105, 0.0, 0.0>
#   Vector3<0.3421052631578947, 0.0, 0.0>
#   Vector3<0.3684210526315789, 0.0, 0.0>
#   Vector3<0.39473684210526316, 0.0, 0.0>
#   Vector3<0.42105263157894735, 0.0, 0.0>
#   Vector3<0.4473684210526315, 0.0, 0.0>
#   Vector3<0.47368421052631576, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.02631578947368421, 0.0>
#   Vector3<0.5, 0.05263157894736842, 0.0>
#   Vector3<0.5, 0.07894736842105263, 0.0>
#   Vector3<0.5, 0.10526315789473684, 0.0>
#   Vector3<0.5, 0.13157894736842105, 0.0>
#   Vector3<0.5, 0.15789473684210525, 0.0>
#   Vector3<0.5, 0.18421052631578946, 0.0>
#   Vector3<0.5, 0.21052631578947367, 0.0>
#   Vector3<0.5, 0.23684210526315788, 0.0>
#   Vector3<0.5, 0.2631578947368421, 0.0>
#   Vector3<0.5, 0.2894736842105263, 0.0>
#   Vector3<0.5, 0.3157894736842105, 0.0>
#   Vector3<0.5, 0.3421052631578947, 0.0>
#   Vector3<0.5, 0.3684210526315789, 0.0>
#   Vector3<0.5, 0.39473684210526316, 0.0>
#   Vector3<0.5, 0.42105263157894735, 0.0>
#   Vector3<0.5, 0.4473684210526315, 0.0>
#   Vector3<0.5, 0.47368421052631576, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4736842105263158, 0.4736842105263158, 0.0>
#   Vector3<0.4473684210526316, 0.4473684210526316, 0.0>
#   Vector3<0.42105263157894735, 0.42105263157894735, 0.0>
#   Vector3<0.39473684210526316, 0.39473684210526316, 0.0>
#   Vector3<0.368421052631579, 0.368421052631579, 0.0>
#   Vector3<0.34210526315789475, 0.34210526315789475, 0.0>
#   Vector3<0.3157894736842105, 0.3157894736842105, 0.0>
#   Vector3<0.2894736842105263, 0.2894736842105263, 0.0>
#   Vector3<0.26315789473684215, 0.26315789473684215, 0.0>
#   Vector3<0.2368421052631579, 0.2368421052631579, 0.0>
#   Vector3<0.21052631578947367, 0.21052631578947367, 0.0>
#   Vector3<0.1842105263157895, 0.1842105263157895, 0.0>
#   Vector3<0.1578947368421053, 0.1578947368421053, 0.0>
#   Vector3<0.13157894736842107, 0.13157894736842107, 0.0>
#   Vector3<0.10526315789473684, 0.10526315789473684, 0.0>
#   Vector3<0.07894736842105265, 0.07894736842105265, 0.0>
#   Vector3<0.052631578947368474, 0.052631578947368474, 0.0>
#   Vector3<0.026315789473684237, 0.026315789473684237, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.023144960403442383
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     iteration    1: trace = 13.52204353650851 (195.397% change)
#     iteration    2: trace = 5.287635231467371 (87.555% change)
#     iteration    3: trace = 4.840931258274304 (8.82068% change)
#     iteration    4: trace = 4.719961865100553 (2.5305% change)
#     iteration    5: trace = 4.677680118671256 (0.899837% change)
#     iteration    6: trace = 4.669771319476373 (0.169218% change)
#     iteration    7: trace = 4.666739950358916 (0.0649358% change)
#     iteration    8: trace = 4.66599540417806 (0.0159556% change)
#     iteration    9: trace = 4.665861883193496 (0.00286162% change)
#     iteration   10: trace = 4.665805391447788 (0.00121075% change)
#     iteration   11: trace = 4.665782735413637 (0.000485577% change)
#     iteration   12: trace = 4.66577559687379 (0.000152998% change)
#     iteration   13: trace = 4.665773578966511 (4.32491e-05% change)
#     iteration   14: trace = 4.665773213611196 (7.83054e-06% change)
# Finished solving for bands 2 to 8 after 14 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.613709, 0.627741, 0.627741, 0.657833, 0.965641, 0.991192, 1.07394
# elapsed time for k point: 0.061690568923950195
# solve_kpoint (0.0263158,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.665524993663481 (0.0663319% change)
#     iteration    2: trace = 4.663902235031292 (0.034788% change)
#     iteration    3: trace = 4.663589551684397 (0.00670455% change)
#     iteration    4: trace = 4.663516818321657 (0.00155961% change)
#     iteration    5: trace = 4.663498423939025 (0.000394432% change)
#     iteration    6: trace = 4.663492265021612 (0.000132067% change)
#     iteration    7: trace = 4.66348452596795 (0.00016595% change)
#     iteration    8: trace = 4.66347723363295 (0.000156371% change)
#     iteration    9: trace = 4.663464051702781 (0.000282664% change)
#     large trace change predicted (0.000639375%)
#     iteration   10: trace = 4.66343426953634 (0.00063863% change)
#     large trace change predicted (0.00144196%)
#     iteration   11: trace = 4.663367078412277 (0.00144082% change)
#     iteration   12: trace = 4.663252732783024 (0.00245203% change)
#     iteration   13: trace = 4.663171342761175 (0.00174536% change)
#     iteration   14: trace = 4.663150938198729 (0.000437569% change)
#     iteration   15: trace = 4.663143355591918 (0.000162607% change)
#     iteration   16: trace = 4.663142212980132 (2.4503e-05% change)
#     iteration   17: trace = 4.663141779934573 (9.28656e-06% change)
# Finished solving for bands 1 to 8 after 17 iterations.
# tmfreqs:, 2, 0.0263158, 0, 0, 0.0263158, 0.0174811, 0.608227, 0.627837, 0.629561, 0.661568, 0.964869, 0.989235, 1.07477
# elapsed time for k point: 0.046511173248291016
# solve_kpoint (0.0526316,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.657953210090755 (0.0630625% change)
#     iteration    2: trace = 4.656584295549862 (0.0293931% change)
#     iteration    3: trace = 4.656336081455045 (0.00533053% change)
#     iteration    4: trace = 4.656291926051839 (0.000948291% change)
#     iteration    5: trace = 4.656283448331163 (0.00018207% change)
#     iteration    6: trace = 4.656282526280467 (1.98023e-05% change)
#     iteration    7: trace = 4.656282357463682 (3.62557e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 3, 0.0526316, 0, 0, 0.0526316, 0.0349521, 0.597108, 0.628122, 0.631683, 0.670786, 0.962637, 0.983882, 1.07718
# elapsed time for k point: 0.02003765106201172
# solve_kpoint (0.0789474,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.648434371500187 (0.051579% change)
#     iteration    2: trace = 4.647508214242295 (0.0199261% change)
#     iteration    3: trace = 4.647351229768758 (0.00337788% change)
#     iteration    4: trace = 4.647324369866774 (0.000577963% change)
#     iteration    5: trace = 4.647318289962886 (0.000130826% change)
#     iteration    6: trace = 4.647317252299163 (2.23282e-05% change)
#     iteration    7: trace = 4.647316925630629 (7.02919e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 4, 0.0789474, 0, 0, 0.0789474, 0.0524026, 0.584127, 0.628592, 0.633242, 0.68257, 0.959168, 0.976211, 1.0809
# elapsed time for k point: 0.01810741424560547
# solve_kpoint (0.105263,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.638834858388742 (0.0418678% change)
#     iteration    2: trace = 4.638211341645033 (0.0134421% change)
#     iteration    3: trace = 4.638105527840444 (0.00228138% change)
#     iteration    4: trace = 4.638083051466126 (0.000484604% change)
#     iteration    5: trace = 4.63807564146973 (0.000159764% change)
#     iteration    6: trace = 4.63807378508224 (4.0025e-05% change)
#     iteration    7: trace = 4.638073231171803 (1.19427e-05% change)
#     iteration    8: trace = 4.638073033435318 (4.26333e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 5, 0.105263, 0, 0, 0.105263, 0.0698219, 0.570328, 0.629235, 0.634678, 0.695427, 0.954746, 0.967192, 1.08561
# elapsed time for k point: 0.026464223861694336
# solve_kpoint (0.131579,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.630268553114764 (0.0354658% change)
#     iteration    2: trace = 4.629805914224315 (0.00999212% change)
#     iteration    3: trace = 4.629713448385352 (0.00199721% change)
#     iteration    4: trace = 4.629680760607222 (0.000706046% change)
#     iteration    5: trace = 4.62966684875283 (0.000300493% change)
#     iteration    6: trace = 4.629661439088198 (0.000116848% change)
#     large trace change predicted (0.000274503%)
#     iteration    7: trace = 4.629648731350768 (0.000274486% change)
#     near maximum in trace
#     iteration    8: trace = 4.625721828718339 (0.0848567% change)
#     iteration    9: trace = 4.62566625219011 (0.00120147% change)
#     iteration   10: trace = 4.625607568235067 (0.00126867% change)
#     iteration   11: trace = 4.625545588991194 (0.00133992% change)
#     iteration   12: trace = 4.625479925445792 (0.00141959% change)
#     iteration   13: trace = 4.625410000292149 (0.00151175% change)
#     iteration   14: trace = 4.625335047748116 (0.00162047% change)
#     iteration   15: trace = 4.625254100012365 (0.00175011% change)
#     iteration   16: trace = 4.625165963578889 (0.00190557% change)
#     iteration   17: trace = 4.625069192531611 (0.00209229% change)
#     iteration   18: trace = 4.62496207373375 (0.00231607% change)
#     iteration   19: trace = 4.624842654505741 (0.00258209% change)
#     iteration   20: trace = 4.624708870342976 (0.00289277% change)
#     iteration   21: trace = 4.624558863116699 (0.00324366% change)
#     iteration   22: trace = 4.624391581569405 (0.00361731% change)
#     iteration   23: trace = 4.624207628532093 (0.00397797% change)
#     iteration   24: trace = 4.62400997633569 (0.00427438% change)
#     iteration   25: trace = 4.623803847996836 (0.00445788% change)
#     iteration   26: trace = 4.623595421060912 (0.0045078% change)
#     iteration   27: trace = 4.62339007305753 (0.0044414% change)
#     iteration   28: trace = 4.623191315272308 (0.00429905% change)
#     iteration   29: trace = 4.623000766402557 (0.00412167% change)
#     iteration   30: trace = 4.622818703347435 (0.00393828% change)
#     iteration   31: trace = 4.622644667130669 (0.00376479% change)
#     iteration   32: trace = 4.622477898135939 (0.00360772% change)
#     iteration   33: trace = 4.622317588130863 (0.00346811% change)
#     iteration   34: trace = 4.622163004956587 (0.00334433% change)
#     iteration   35: trace = 4.622013543933884 (0.00323363% change)
#     iteration   36: trace = 4.621868741721249 (0.00313293% change)
#     iteration   37: trace = 4.621728272613521 (0.00303927% change)
#     iteration   38: trace = 4.621591937176121 (0.00294992% change)
#     iteration   39: trace = 4.621459647387267 (0.00286247% change)
#     iteration   40: trace = 4.621331409498785 (0.00277487% change)
#     iteration   41: trace = 4.621207304547458 (0.00268552% change)
#     iteration   42: trace = 4.621087466242772 (0.00259326% change)
#     iteration   43: trace = 4.620972056455591 (0.00249749% change)
#     iteration   44: trace = 4.620861239414151 (0.00239816% change)
#     iteration   45: trace = 4.620755156613287 (0.00229576% change)
#     iteration   46: trace = 4.620653904970824 (0.00219126% change)
#     iteration   47: trace = 4.620557520641328 (0.00208597% change)
#     iteration   48: trace = 4.620465970086556 (0.00198139% change)
#     iteration   49: trace = 4.620379148752053 (0.00187908% change)
#     iteration   50: trace = 4.620296886428596 (0.00178044% change)
#     iteration   51: trace = 4.620218957468865 (0.00168668% change)
#     iteration   52: trace = 4.620145093673771 (0.00159872% change)
#     iteration   53: trace = 4.620074997820331 (0.00151719% change)
#     iteration   54: trace = 4.620008356287676 (0.00144244% change)
#     iteration   55: trace = 4.619944849831292 (0.00137461% change)
#     iteration   56: trace = 4.619884162094031 (0.00131361% change)
#     iteration   57: trace = 4.619825985841272 (0.00125927% change)
#     iteration   58: trace = 4.619770027152925 (0.00121128% change)
#     iteration   59: trace = 4.619716007920777 (0.00116931% change)
#     iteration   60: trace = 4.619663667025384 (0.001133% change)
#     iteration   61: trace = 4.619612760539087 (0.00110196% change)
#     iteration   62: trace = 4.61956306124898 (0.00107584% change)
#     iteration   63: trace = 4.619514357733992 (0.00105429% change)
#     iteration   64: trace = 4.61946645317424 (0.00103701% change)
#     iteration   65: trace = 4.619419164022993 (0.0010237% change)
#     iteration   66: trace = 4.619372318633354 (0.0010141% change)
#     iteration   67: trace = 4.619325755902884 (0.00100799% change)
#     iteration   68: trace = 4.619279323978583 (0.00100517% change)
#     iteration   69: trace = 4.619232879049699 (0.00100546% change)
#     resetting CG direction...
#     large trace change predicted (0.403955%)
#     iteration   70: trace = 4.600609132951229 (0.403993% change)
#     iteration   71: trace = 4.596257005625592 (0.0946437% change)
#     iteration   72: trace = 4.595709568130101 (0.0119112% change)
#     iteration   73: trace = 4.59558265513185 (0.00276159% change)
#     iteration   74: trace = 4.595562671538495 (0.000434844% change)
#     iteration   75: trace = 4.595548226161284 (0.000314334% change)
#     iteration   76: trace = 4.595542474825695 (0.00012515% change)
#     iteration   77: trace = 4.595541314792671 (2.52426e-05% change)
#     iteration   78: trace = 4.595540759779073 (1.20772e-05% change)
#     iteration   79: trace = 4.595540112106865 (1.40935e-05% change)
#     iteration   80: trace = 4.595539793987022 (6.92236e-06% change)
# Finished solving for bands 1 to 8 after 80 iterations.
# tmfreqs:, 6, 0.131579, 0, 0, 0.131579, 0.0871983, 0.556082, 0.630039, 0.636207, 0.708756, 0.949659, 0.957491, 1.07519
# elapsed time for k point: 0.19028568267822266
# solve_kpoint (0.157895,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.557153214301387 (0.0574058% change)
#     iteration    2: trace = 4.555754591218952 (0.0306954% change)
#     iteration    3: trace = 4.555377950156362 (0.00826771% change)
#     iteration    4: trace = 4.555250694222877 (0.00279357% change)
#     iteration    5: trace = 4.555229778582063 (0.000459156% change)
#     iteration    6: trace = 4.555227044163417 (6.00281e-05% change)
#     iteration    7: trace = 4.555226433259326 (1.34111e-05% change)
#     iteration    8: trace = 4.555226283160861 (3.29508e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 7, 0.157895, 0, 0, 0.157895, 0.104519, 0.541556, 0.630985, 0.637901, 0.722306, 0.944159, 0.947528, 1.06536
# elapsed time for k point: 0.02855539321899414
# solve_kpoint (0.184211,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.51463573394219 (0.0406889% change)
#     iteration    2: trace = 4.513923920425604 (0.015768% change)
#     iteration    3: trace = 4.513774815936204 (0.00330327% change)
#     iteration    4: trace = 4.513734541942443 (0.00089225% change)
#     iteration    5: trace = 4.513727998988921 (0.000144957% change)
#     iteration    6: trace = 4.513727371984768 (1.3891e-05% change)
#     iteration    7: trace = 4.513727264132261 (2.38943e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 8, 0.184211, 0, 0, 0.184211, 0.12177, 0.526834, 0.632053, 0.639774, 0.735956, 0.93758, 0.938457, 1.05411
# elapsed time for k point: 0.0218963623046875
# solve_kpoint (0.210526,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.473726947519905 (0.0315827% change)
#     iteration    2: trace = 4.473315290564863 (0.00920208% change)
#     iteration    3: trace = 4.473244950373553 (0.00157245% change)
#     iteration    4: trace = 4.473229804189191 (0.000338596% change)
#     iteration    5: trace = 4.47322745568588 (5.25013e-05% change)
#     iteration    6: trace = 4.473227252337628 (4.5459e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 9, 0.210526, 0, 0, 0.210526, 0.138934, 0.51197, 0.633217, 0.641809, 0.749645, 0.927837, 0.932721, 1.04217
# elapsed time for k point: 0.018858909606933594
# solve_kpoint (0.236842,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.435142064879246 (0.0261385% change)
#     iteration    2: trace = 4.434880561900128 (0.00589633% change)
#     iteration    3: trace = 4.434842453983587 (0.000859281% change)
#     iteration    4: trace = 4.434835588081185 (0.000154817% change)
#     iteration    5: trace = 4.434834579001683 (2.27535e-05% change)
#     iteration    6: trace = 4.434834481587389 (2.19657e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 10, 0.236842, 0, 0, 0.236842, 0.15599, 0.497003, 0.63445, 0.643978, 0.763337, 0.918445, 0.92709, 1.02982
# elapsed time for k point: 0.019675254821777344
# solve_kpoint (0.263158,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.399391013333409 (0.0226116% change)
#     iteration    2: trace = 4.399213288849001 (0.00403983% change)
#     iteration    3: trace = 4.399190546555961 (0.000516964% change)
#     iteration    4: trace = 4.399186933507857 (8.21299e-05% change)
#     iteration    5: trace = 4.399186431137011 (1.14196e-05% change)
#     iteration    6: trace = 4.399186375743863 (1.25917e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 11, 0.263158, 0, 0, 0.263158, 0.172911, 0.481968, 0.635719, 0.646238, 0.777012, 0.909524, 0.921679, 1.01723
# elapsed time for k point: 0.01797962188720703
# solve_kpoint (0.289474,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.366829295323271 (0.0201923% change)
#     iteration    2: trace = 4.366702072029749 (0.00291344% change)
#     iteration    3: trace = 4.366687565589078 (0.000332206% change)
#     iteration    4: trace = 4.366685432806718 (4.88421e-05% change)
#     iteration    5: trace = 4.366685160100491 (6.24515e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 12, 0.289474, 0, 0, 0.289474, 0.189663, 0.466907, 0.636991, 0.648539, 0.790654, 0.901182, 0.916584, 1.00447
# elapsed time for k point: 0.01551365852355957
# solve_kpoint (0.315789,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.337707328073195 (0.0184675% change)
#     iteration    2: trace = 4.337612155388832 (0.0021941% change)
#     iteration    3: trace = 4.337602401483809 (0.000224868% change)
#     iteration    4: trace = 4.337601028005721 (3.16645e-05% change)
#     iteration    5: trace = 4.337600872020215 (3.59612e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 13, 0.315789, 0, 0, 0.315789, 0.206192, 0.451872, 0.638232, 0.650819, 0.804247, 0.893525, 0.911888, 0.99159
# elapsed time for k point: 0.024280786514282227
# solve_kpoint (0.342105,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.312204350653938 (0.0172022% change)
#     iteration    2: trace = 4.312130375954383 (0.00171549% change)
#     iteration    3: trace = 4.312123590112108 (0.000157366% change)
#     iteration    4: trace = 4.312122668359589 (2.13758e-05% change)
#     iteration    5: trace = 4.312122577891262 (2.098e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 14, 0.342105, 0, 0, 0.342105, 0.222423, 0.436939, 0.639403, 0.653012, 0.817775, 0.886662, 0.907664, 0.978619
# elapsed time for k point: 0.0211641788482666
# solve_kpoint (0.368421,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.29045119694611 (0.0162636% change)
#     iteration    2: trace = 4.290391544598356 (0.00139036% change)
#     iteration    3: trace = 4.290386652478729 (0.000114025% change)
#     iteration    4: trace = 4.290386013428183 (1.48949e-05% change)
#     iteration    5: trace = 4.290385959761879 (1.25085e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 15, 0.368421, 0, 0, 0.368421, 0.238232, 0.422233, 0.64047, 0.655046, 0.831198, 0.880717, 0.903976, 0.965577
# elapsed time for k point: 0.018882274627685547
# solve_kpoint (0.394737,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.272543601809115 (0.0155645% change)
#     iteration    2: trace = 4.272493746966701 (0.00116687% change)
#     iteration    3: trace = 4.272490087314292 (8.56562e-05% change)
#     iteration    4: trace = 4.272489633504369 (1.06217e-05% change)
#     iteration    5: trace = 4.272489600759378 (7.66415e-07% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 16, 0.394737, 0, 0, 0.394737, 0.253403, 0.407966, 0.641397, 0.656845, 0.844409, 0.875888, 0.900879, 0.952479
# elapsed time for k point: 0.022015094757080078
# solve_kpoint (0.421053,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.258551334448845 (0.0150493% change)
#     iteration    2: trace = 4.258508154989555 (0.00101395% change)
#     iteration    3: trace = 4.258505297638962 (6.70975e-05% change)
#     iteration    4: trace = 4.25850496694306 (7.76554e-06% change)
# Finished solving for bands 1 to 8 after 4 iterations.
# tmfreqs:, 17, 0.421053, 0, 0, 0.421053, 0.26754, 0.394533, 0.642155, 0.658339, 0.856866, 0.872791, 0.898419, 0.939339
# elapsed time for k point: 0.014733552932739258
# solve_kpoint (0.447368,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.248524019388967 (0.0146829% change)
#     iteration    2: trace = 4.248485245562696 (0.000912646% change)
#     iteration    3: trace = 4.248482864596228 (5.60427e-05% change)
#     iteration    4: trace = 4.248482610560173 (5.97945e-06% change)
# Finished solving for bands 1 to 8 after 4 iterations.
# tmfreqs:, 18, 0.447368, 0, 0, 0.447368, 0.279867, 0.382711, 0.642716, 0.65946, 0.864391, 0.875668, 0.896634, 0.926175
# elapsed time for k point: 0.017468929290771484
# solve_kpoint (0.473684,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.242494696952448 (0.0144382% change)
#     iteration    2: trace = 4.242458601835934 (0.000850803% change)
#     iteration    3: trace = 4.2424565229132 (4.90028e-05% change)
#     iteration    4: trace = 4.242456316257417 (4.87114e-06% change)
# Finished solving for bands 1 to 8 after 4 iterations.
# tmfreqs:, 19, 0.473684, 0, 0, 0.473684, 0.288883, 0.373997, 0.643061, 0.660155, 0.864612, 0.886915, 0.895552, 0.913023
# elapsed time for k point: 0.01729130744934082
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.24048245745869 (0.0143038% change)
#     iteration    2: trace = 4.240447591600575 (0.000822218% change)
#     iteration    3: trace = 4.240445637461834 (4.60833e-05% change)
#     iteration    4: trace = 4.240445449326633 (4.43668e-06% change)
# Finished solving for bands 1 to 8 after 4 iterations.
# tmfreqs:, 20, 0.5, 0, 0, 0.5, 0.292334, 0.370648, 0.643178, 0.660391, 0.864297, 0.895189, 0.898672, 0.901015
# elapsed time for k point: 0.01851963996887207
# solve_kpoint (0.5,0.0263158,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.242005344744754 (0.0261945% change)
#     iteration    2: trace = 4.241921159094765 (0.00198459% change)
#     iteration    3: trace = 4.241916734726153 (0.000104301% change)
#     iteration    4: trace = 4.241916178268764 (1.31181e-05% change)
#     iteration    5: trace = 4.241916151956254 (6.20298e-07% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 21, 0.5, 0.0263158, 0, 0.500692, 0.29272, 0.371098, 0.636537, 0.667059, 0.857849, 0.898682, 0.901041, 0.901643
# elapsed time for k point: 0.017935991287231445
# solve_kpoint (0.5,0.0526316,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.246410472719353 (0.0262979% change)
#     iteration    2: trace = 4.246322893187179 (0.00206246% change)
#     iteration    3: trace = 4.24631804018572 (0.000114287% change)
#     iteration    4: trace = 4.246317445823445 (1.39971e-05% change)
#     iteration    5: trace = 4.246317410421804 (8.33702e-07% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 22, 0.5, 0.0526316, 0, 0.502762, 0.293874, 0.372442, 0.625216, 0.678463, 0.845104, 0.898759, 0.901119, 0.914358
# elapsed time for k point: 0.017702817916870117
# solve_kpoint (0.5,0.0789474,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.253716766203599 (0.026564% change)
#     iteration    2: trace = 4.253622607185511 (0.00221359% change)
#     iteration    3: trace = 4.253616965699631 (0.000132628% change)
#     iteration    4: trace = 4.253616293608382 (1.58005e-05% change)
#     iteration    5: trace = 4.253616242131361 (1.21019e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 23, 0.5, 0.0789474, 0, 0.506194, 0.295784, 0.37466, 0.613178, 0.690641, 0.830814, 0.898876, 0.901247, 0.928606
# elapsed time for k point: 0.021250247955322266
# solve_kpoint (0.5,0.105263,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.263868432355255 (0.0269966% change)
#     iteration    2: trace = 4.263764137106265 (0.00244605% change)
#     iteration    3: trace = 4.263757271959245 (0.000161012% change)
#     iteration    4: trace = 4.263756467278934 (1.88726e-05% change)
#     iteration    5: trace = 4.263756391703042 (1.77252e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 24, 0.5, 0.105263, 0, 0.51096, 0.29843, 0.377718, 0.600979, 0.703036, 0.816098, 0.899036, 0.90142, 0.943266
# elapsed time for k point: 0.020264148712158203
# solve_kpoint (0.5,0.131579,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.276784609782856 (0.0276025% change)
#     iteration    2: trace = 4.276666023721286 (0.00277282% change)
#     iteration    3: trace = 4.276657371385316 (0.000202315% change)
#     iteration    4: trace = 4.276656353962696 (2.37901e-05% change)
#     iteration    5: trace = 4.276656244517024 (2.55914e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 25, 0.5, 0.131579, 0, 0.517023, 0.301785, 0.381571, 0.588766, 0.715507, 0.801297, 0.899233, 0.901633, 0.957992
# elapsed time for k point: 0.01715540885925293
# solve_kpoint (0.5,0.157895,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.292356271706423 (0.0283927% change)
#     iteration    2: trace = 4.29221835736445 (0.00321307% change)
#     iteration    3: trace = 4.292207146008058 (0.000261202% change)
#     iteration    4: trace = 4.292205796018873 (3.14521e-05% change)
#     iteration    5: trace = 4.292205639794743 (3.63972e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 26, 0.5, 0.157895, 0, 0.524338, 0.305816, 0.38616, 0.576601, 0.727994, 0.786573, 0.899464, 0.90188, 0.972625
# elapsed time for k point: 0.018924951553344727
# solve_kpoint (0.5,0.184211,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.31044175141327 (0.0293834% change)
#     iteration    2: trace = 4.310278213997313 (0.00379405% change)
#     iteration    3: trace = 4.310263346677615 (0.000344928% change)
#     iteration    4: trace = 4.310261484889486 (4.31943e-05% change)
#     iteration    5: trace = 4.310261263186837 (5.1436e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 27, 0.5, 0.184211, 0, 0.532854, 0.31048, 0.391413, 0.564522, 0.74046, 0.772029, 0.899723, 0.902152, 0.987058
# elapsed time for k point: 0.018378734588623047
# solve_kpoint (0.5,0.210526,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.330860453733252 (0.0305976% change)
#     iteration    2: trace = 4.330663236923442 (0.00455386% change)
#     iteration    3: trace = 4.330643122176379 (0.000464474% change)
#     iteration    4: trace = 4.330640483089403 (6.09399e-05% change)
#     iteration    5: trace = 4.330640166426862 (7.31214e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 28, 0.5, 0.210526, 0, 0.542514, 0.315732, 0.397245, 0.552564, 0.752878, 0.757755, 0.900002, 0.90244, 1.0012
# elapsed time for k point: 0.0207669734954834
# solve_kpoint (0.5,0.236842,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.353384140171729 (0.0320666% change)
#     iteration    2: trace = 4.35314273960687 (0.00554528% change)
#     iteration    3: trace = 4.353115048785694 (0.000636113% change)
#     iteration    4: trace = 4.353111243568947 (8.74137e-05% change)
#     iteration    5: trace = 4.353110782106527 (1.06008e-05% change)
#     iteration    6: trace = 4.353110695147548 (1.99763e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 29, 0.5, 0.236842, 0, 0.553258, 0.321517, 0.403555, 0.540761, 0.743839, 0.765216, 0.900295, 0.902732, 1.01496
# elapsed time for k point: 0.023349285125732422
# solve_kpoint (0.5,0.263158,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.377724900266307 (0.0338344% change)
#     iteration    2: trace = 4.377425266223401 (0.00684475% change)
#     iteration    3: trace = 4.377386767127088 (0.000879496% change)
#     iteration    4: trace = 4.377381265092911 (0.000125692% change)
#     iteration    5: trace = 4.377380575739497 (1.57481e-05% change)
#     iteration    6: trace = 4.37738041577567 (3.65433e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 30, 0.5, 0.263158, 0, 0.565024, 0.327771, 0.410228, 0.529153, 0.73038, 0.777441, 0.900593, 0.903015, 1.02824
# elapsed time for k point: 0.027030229568481445
# solve_kpoint (0.5,0.289474,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.40351890841855 (0.0359539% change)
#     iteration    2: trace = 4.403142599746403 (0.008546% change)
#     iteration    3: trace = 4.403088330312706 (0.00123252% change)
#     iteration    4: trace = 4.403080293723954 (0.000182522% change)
#     iteration    5: trace = 4.403079206304605 (2.46968e-05% change)
#     iteration    6: trace = 4.40307890656424 (6.80752e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 31, 0.5, 0.289474, 0, 0.57775, 0.334421, 0.417127, 0.517791, 0.717491, 0.789508, 0.900889, 0.903272, 1.04092
# elapsed time for k point: 0.020832538604736328
# solve_kpoint (0.5,0.315789,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.430304196540398 (0.0384993% change)
#     iteration    2: trace = 4.429826346290641 (0.0107865% change)
#     iteration    3: trace = 4.429749342187924 (0.00173832% change)
#     iteration    4: trace = 4.429737553495086 (0.000266126% change)
#     iteration    5: trace = 4.4297357296891 (4.11719e-05% change)
#     iteration    6: trace = 4.429735155863614 (1.29539e-05% change)
#     iteration    7: trace = 4.429735094796866 (1.37856e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 32, 0.5, 0.315789, 0, 0.591374, 0.341377, 0.424091, 0.50674, 0.70531, 0.801355, 0.901173, 0.903487, 1.05286
# elapsed time for k point: 0.022670269012451172
# solve_kpoint (0.5,0.342105,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.457490897137282 (0.0415642% change)
#     iteration    2: trace = 4.456878048326501 (0.0137497% change)
#     iteration    3: trace = 4.456768533831852 (0.00245723% change)
#     iteration    4: trace = 4.456751262473202 (0.000387532% change)
#     iteration    5: trace = 4.456747987527438 (7.34828e-05% change)
#     iteration    6: trace = 4.456746868136443 (2.51168e-05% change)
#     iteration    7: trace = 4.456746745544113 (2.75071e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 33, 0.5, 0.342105, 0, 0.605835, 0.348522, 0.430933, 0.496095, 0.694002, 0.812892, 0.901439, 0.903634, 1.0639
# elapsed time for k point: 0.02263188362121582
# solve_kpoint (0.5,0.368421,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.484321706314409 (0.045262% change)
#     iteration    2: trace = 4.483529565739818 (0.0176662% change)
#     iteration    3: trace = 4.48337404964489 (0.00346867% change)
#     iteration    4: trace = 4.483348209714511 (0.000576352% change)
#     iteration    5: trace = 4.483341870523487 (0.000141394% change)
#     iteration    6: trace = 4.483339645184696 (4.96357e-05% change)
#     iteration    7: trace = 4.483339382560015 (5.85779e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 34, 0.5, 0.368421, 0, 0.621075, 0.355701, 0.437431, 0.485993, 0.683764, 0.823984, 0.901679, 0.903685, 1.07384
# elapsed time for k point: 0.022923707962036133
# solve_kpoint (0.5,0.394737,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.509819683167586 (0.0497281% change)
#     iteration    2: trace = 4.508789980405883 (0.0228351% change)
#     iteration    3: trace = 4.508570097079237 (0.00487689% change)
#     iteration    4: trace = 4.508529662226723 (0.000896848% change)
#     iteration    5: trace = 4.508512659070511 (0.000377134% change)
#     iteration    6: trace = 4.508479435603615 (0.000736908% change)
#     near maximum in trace
#     iteration    7: trace = 4.494091725820624 (0.319636% change)
#     iteration    8: trace = 4.49404712638076 (0.000992407% change)
#     iteration    9: trace = 4.494001476162637 (0.0010158% change)
#     iteration   10: trace = 4.49395475982923 (0.00103953% change)
#     iteration   11: trace = 4.493906952226442 (0.00106383% change)
#     iteration   12: trace = 4.493858018581653 (0.00108889% change)
#     iteration   13: trace = 4.493807914735462 (0.00111495% change)
#     iteration   14: trace = 4.493756587356111 (0.00114219% change)
#     iteration   15: trace = 4.493703974096077 (0.00117081% change)
#     iteration   16: trace = 4.49365000372029 (0.00120103% change)
#     iteration   17: trace = 4.493594596067608 (0.00123303% change)
#     iteration   18: trace = 4.493537662006992 (0.00126701% change)
#     iteration   19: trace = 4.493479103260648 (0.00130319% change)
#     iteration   20: trace = 4.493418812145665 (0.00134176% change)
#     iteration   21: trace = 4.493356671229294 (0.00138294% change)
#     iteration   22: trace = 4.493292552903119 (0.00142697% change)
#     iteration   23: trace = 4.493226318883147 (0.00147408% change)
#     iteration   24: trace = 4.493157819639278 (0.00152451% change)
#     iteration   25: trace = 4.493086893797983 (0.00157854% change)
#     iteration   26: trace = 4.49301336745091 (0.00163645% change)
#     iteration   27: trace = 4.492937053496336 (0.00169852% change)
#     iteration   28: trace = 4.492857750955316 (0.00176506% change)
#     iteration   29: trace = 4.492775244325156 (0.00183641% change)
#     iteration   30: trace = 4.492689303003117 (0.0019129% change)
#     iteration   31: trace = 4.492599680829027 (0.00199486% change)
#     iteration   32: trace = 4.492506115808142 (0.00208267% change)
#     iteration   33: trace = 4.492408330090566 (0.00217666% change)
#     iteration   34: trace = 4.492306030301435 (0.0022772% change)
#     iteration   35: trace = 4.492198908336466 (0.00238459% change)
#     iteration   36: trace = 4.492086642760622 (0.00249915% change)
#     iteration   37: trace = 4.491968900973729 (0.00262113% change)
#     iteration   38: trace = 4.491845342334846 (0.00275069% change)
#     iteration   39: trace = 4.491715622467964 (0.00288794% change)
#     iteration   40: trace = 4.491579399004176 (0.00303282% change)
#     iteration   41: trace = 4.491436339050046 (0.00318512% change)
#     iteration   42: trace = 4.491286128707896 (0.00334443% change)
#     iteration   43: trace = 4.491128485008565 (0.00351005% change)
#     iteration   44: trace = 4.490963170643894 (0.00368098% change)
#     iteration   45: trace = 4.49079001188707 (0.00385579% change)
#     iteration   46: trace = 4.490608920027462 (0.0040326% change)
#     iteration   47: trace = 4.490419916454278 (0.00420895% change)
#     iteration   48: trace = 4.490223161093035 (0.00438177% change)
#     iteration   49: trace = 4.490018983086087 (0.00454727% change)
#     iteration   50: trace = 4.489807911279793 (0.00470102% change)
#     iteration   51: trace = 4.489590700221878 (0.00483799% change)
#     iteration   52: trace = 4.489368345275823 (0.0049528% change)
#     iteration   53: trace = 4.489142078924282 (0.00504018% change)
#     iteration   54: trace = 4.488913340658337 (0.0050955% change)
#     iteration   55: trace = 4.488683716341968 (0.0051155% change)
#     iteration   56: trace = 4.488454849867525 (0.00509887% change)
#     iteration   57: trace = 4.488228338466829 (0.00504666% change)
#     iteration   58: trace = 4.488005629523395 (0.00496219% change)
#     iteration   59: trace = 4.487787937560101 (0.00485065% change)
#     iteration   60: trace = 4.487576194406603 (0.00471832% change)
#     iteration   61: trace = 4.487371036077706 (0.0045718% change)
#     iteration   62: trace = 4.48717282099365 (0.00441727% change)
#     iteration   63: trace = 4.486981669038921 (0.00426005% change)
#     iteration   64: trace = 4.486797510194809 (0.00410438% change)
#     iteration   65: trace = 4.486620133718557 (0.00395338% change)
#     iteration   66: trace = 4.486449232176689 (0.00380921% change)
#     iteration   67: trace = 4.48628443769123 (0.00367323% change)
#     iteration   68: trace = 4.486125349917021 (0.00354615% change)
#     iteration   69: trace = 4.485971556502404 (0.00342826% change)
#     resetting CG direction...
#     large trace change predicted (4.28585%)
#     iteration   70: trace = 4.292895467321436 (4.39866% change)
#     iteration   71: trace = 4.278975703153314 (0.324778% change)
#     iteration   72: trace = 4.278224894921069 (0.017548% change)
#     iteration   73: trace = 4.278157408313707 (0.00157746% change)
#     iteration   74: trace = 4.278149083822592 (0.000194581% change)
#     iteration   75: trace = 4.278147879204272 (2.81575e-05% change)
#     iteration   76: trace = 4.278147643072645 (5.51948e-06% change)
# Finished solving for bands 1 to 8 after 76 iterations.
# tmfreqs:, 35, 0.5, 0.394737, 0, 0.637038, 0.362687, 0.443334, 0.476639, 0.674831, 0.834415, 0.901885, 0.903603, 0.970224
# elapsed time for k point: 0.17172980308532715
# solve_kpoint (0.5,0.421053,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.268429923998748 (0.0224586% change)
#     iteration    2: trace = 4.268314066453335 (0.00271433% change)
#     iteration    3: trace = 4.268304643857214 (0.000220757% change)
#     iteration    4: trace = 4.268303706810703 (2.19536e-05% change)
#     iteration    5: trace = 4.268303632452927 (1.74209e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 36, 0.5, 0.421053, 0, 0.653671, 0.369147, 0.448361, 0.468354, 0.667464, 0.843835, 0.902053, 0.903355, 0.961424
# elapsed time for k point: 0.013322114944458008
# solve_kpoint (0.5,0.447368,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.261407706961426 (0.0225612% change)
#     iteration    2: trace = 4.261289922916301 (0.00276401% change)
#     iteration    3: trace = 4.261280621771486 (0.000218271% change)
#     iteration    4: trace = 4.261279742582552 (2.0632e-05% change)
#     iteration    5: trace = 4.261279677079274 (1.53717e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 37, 0.5, 0.447368, 0, 0.670924, 0.374582, 0.452226, 0.461624, 0.661938, 0.851671, 0.902176, 0.902942, 0.95427
# elapsed time for k point: 0.022878646850585938
# solve_kpoint (0.5,0.473684,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.257197643143367 (0.0226656% change)
#     iteration    2: trace = 4.257078556781521 (0.00279733% change)
#     iteration    3: trace = 4.257069345956448 (0.000216365% change)
#     iteration    4: trace = 4.257068502207615 (1.98199e-05% change)
#     iteration    5: trace = 4.257068441874138 (1.41725e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 38, 0.5, 0.473684, 0, 0.68875, 0.378319, 0.454669, 0.457113, 0.658502, 0.857063, 0.902251, 0.902489, 0.949495
# elapsed time for k point: 0.017201900482177734
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.255795009394575 (0.0227208% change)
#     iteration    2: trace = 4.255675306230615 (0.00281275% change)
#     iteration    3: trace = 4.255666131897485 (0.000215579% change)
#     iteration    4: trace = 4.255665298295169 (1.95881e-05% change)
#     iteration    5: trace = 4.25566523954561 (1.3805e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 39, 0.5, 0.5, 0, 0.707107, 0.379669, 0.455506, 0.455506, 0.657335, 0.859022, 0.902277, 0.902278, 0.947802
# elapsed time for k point: 0.019703388214111328
# solve_kpoint (0.473684,0.473684,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.258730266676579 (0.0454532% change)
#     iteration    2: trace = 4.258490492156619 (0.00563035% change)
#     iteration    3: trace = 4.258472150213943 (0.000430716% change)
#     iteration    4: trace = 4.258470515330202 (3.83913e-05% change)
#     iteration    5: trace = 4.258470404403659 (2.60484e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 40, 0.473684, 0.473684, 0, 0.669891, 0.376948, 0.456093, 0.456487, 0.659662, 0.855322, 0.89892, 0.905966, 0.951009
# elapsed time for k point: 0.018304824829101562
# solve_kpoint (0.447368,0.447368,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.267136466006828 (0.0455991% change)
#     iteration    2: trace = 4.266894495336059 (0.00567072% change)
#     iteration    3: trace = 4.266875763495015 (0.000439005% change)
#     iteration    4: trace = 4.266874114531553 (3.86457e-05% change)
#     iteration    5: trace = 4.266874004138966 (2.5872e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 41, 0.447368, 0.447368, 0, 0.632674, 0.369187, 0.457849, 0.459236, 0.666424, 0.84654, 0.890683, 0.914714, 0.958792
# elapsed time for k point: 0.0180356502532959
# solve_kpoint (0.421053,0.421053,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.281107684769239 (0.0459716% change)
#     iteration    2: trace = 4.280860557667563 (0.00577267% change)
#     iteration    3: trace = 4.280840474799017 (0.000469133% change)
#     iteration    4: trace = 4.280838426569419 (4.78464e-05% change)
#     iteration    5: trace = 4.280838152808403 (6.39503e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 42, 0.421053, 0.421053, 0, 0.595458, 0.357303, 0.460755, 0.463376, 0.677056, 0.835532, 0.880031, 0.92566, 0.96868
# elapsed time for k point: 0.020289182662963867
# solve_kpoint (0.394737,0.394737,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.300576108372551 (0.0465922% change)
#     iteration    2: trace = 4.300319113954548 (0.00597599% change)
#     iteration    3: trace = 4.300295006194428 (0.000560606% change)
#     iteration    4: trace = 4.300290816981896 (9.74169e-05% change)
#     iteration    5: trace = 4.300289429338671 (3.22686e-05% change)
#     iteration    6: trace = 4.300289075510532 (8.22801e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 43, 0.394737, 0.394737, 0, 0.558242, 0.342258, 0.464782, 0.468632, 0.690833, 0.823544, 0.86817, 0.937546, 0.979451
# elapsed time for k point: 0.01608109474182129
# solve_kpoint (0.368421,0.368421,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.325417754921784 (0.0475343% change)
#     iteration    2: trace = 4.32514204782477 (0.00637432% change)
#     iteration    3: trace = 4.325107145260287 (0.000806972% change)
#     iteration    4: trace = 4.325094276054946 (0.000297547% change)
#     iteration    5: trace = 4.325088775581771 (0.000127176% change)
#     iteration    6: trace = 4.325087922406041 (1.97262e-05% change)
#     iteration    7: trace = 4.325087886321005 (8.34319e-07% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 44, 0.368421, 0.368421, 0, 0.521026, 0.32484, 0.46989, 0.47487, 0.707029, 0.811051, 0.855607, 0.949884, 0.990571
# elapsed time for k point: 0.019863605499267578
# solve_kpoint (0.342105,0.342105,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.355389396500111 (0.0490132% change)
#     iteration    2: trace = 4.355071213529675 (0.00730577% change)
#     iteration    3: trace = 4.354998596939215 (0.00166742% change)
#     iteration    4: trace = 4.354944414572611 (0.00124415% change)
#     iteration    5: trace = 4.354924828248859 (0.00044975% change)
#     iteration    6: trace = 4.354922705114015 (4.87525e-05% change)
#     iteration    7: trace = 4.354922612786565 (2.12007e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 45, 0.342105, 0.342105, 0, 0.48381, 0.305648, 0.476031, 0.48204, 0.724997, 0.798251, 0.842601, 0.962459, 1.0017
# elapsed time for k point: 0.025241851806640625
# solve_kpoint (0.315789,0.315789,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.389849484512824 (0.0517667% change)
#     iteration    2: trace = 4.389410369960126 (0.0100035% change)
#     iteration    3: trace = 4.389159150114738 (0.00572348% change)
#     iteration    4: trace = 4.38887909258791 (0.00638087% change)
#     iteration    5: trace = 4.388801186584227 (0.00177509% change)
#     iteration    6: trace = 4.38879338954141 (0.000177658% change)
#     iteration    7: trace = 4.388792766277566 (1.42013e-05% change)
#     iteration    8: trace = 4.388792661911654 (2.37801e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 46, 0.315789, 0.315789, 0, 0.446594, 0.285123, 0.483149, 0.490113, 0.744127, 0.785234, 0.829387, 0.975153, 1.01229
# elapsed time for k point: 0.028099536895751953
# solve_kpoint (0.289474,0.289474,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.426242664936813 (0.0590429% change)
#     iteration    2: trace = 4.425271161804288 (0.0219511% change)
#     iteration    3: trace = 4.423646479206772 (0.0367205% change)
#     iteration    4: trace = 4.421894872098125 (0.0396043% change)
#     iteration    5: trace = 4.421516868806781 (0.00854881% change)
#     iteration    6: trace = 4.421466517370366 (0.00113879% change)
#     iteration    7: trace = 4.421458768136332 (0.000175264% change)
#     iteration    8: trace = 4.421457676132857 (2.46978e-05% change)
#     iteration    9: trace = 4.421457592288162 (1.89631e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 47, 0.289474, 0.289474, 0, 0.409378, 0.263586, 0.491182, 0.499059, 0.763568, 0.772048, 0.816506, 0.987891, 1.01978
# elapsed time for k point: 0.0282900333404541
# solve_kpoint (0.263158,0.263158,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.449920747075785 (0.0783184% change)
#     iteration    2: trace = 4.446784378666078 (0.0705063% change)
#     iteration    3: trace = 4.441704251697461 (0.114308% change)
#     iteration    4: trace = 4.439889214918083 (0.0408719% change)
#     iteration    5: trace = 4.4396027172245 (0.00645302% change)
#     iteration    6: trace = 4.439545073732646 (0.0012984% change)
#     iteration    7: trace = 4.439535442683821 (0.000216938% change)
#     iteration    8: trace = 4.439534231454209 (2.72828e-05% change)
#     iteration    9: trace = 4.439534078125787 (3.45371e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 48, 0.263158, 0.263158, 0, 0.372161, 0.241275, 0.500062, 0.508842, 0.758717, 0.779969, 0.807072, 1.0006, 1.01772
# elapsed time for k point: 0.02835392951965332
# solve_kpoint (0.236842,0.236842,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.455001424929 (0.056742% change)
#     iteration    2: trace = 4.454030866241666 (0.0217882% change)
#     iteration    3: trace = 4.453081238823884 (0.0213229% change)
#     iteration    4: trace = 4.452809844900408 (0.00609471% change)
#     iteration    5: trace = 4.452756598367818 (0.0011958% change)
#     iteration    6: trace = 4.452740330037274 (0.000365355% change)
#     iteration    7: trace = 4.452737398583842 (6.58348e-05% change)
#     iteration    8: trace = 4.452737065242897 (7.4862e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 49, 0.236842, 0.236842, 0, 0.334945, 0.218368, 0.50972, 0.519413, 0.74526, 0.779177, 0.81505, 1.01095, 1.01321
# elapsed time for k point: 0.02554178237915039
# solve_kpoint (0.210526,0.210526,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.470649885542398 (0.0472113% change)
# ...
#     iteration   12: trace = 9.707690075971474 (0.000120804% change)
#     iteration   13: trace = 9.707678314803015 (0.000121153% change)
#     iteration   14: trace = 9.707666520597625 (0.000121494% change)
#     iteration   15: trace = 9.707654694027017 (0.000121827% change)
#     iteration   16: trace = 9.707642835600208 (0.000122155% change)
#     iteration   17: trace = 9.707630945671475 (0.00012248% change)
#     iteration   18: trace = 9.707619024448292 (0.000122803% change)
#     iteration   19: trace = 9.707607071999034 (0.000123124% change)
#     iteration   20: trace = 9.707595088260312 (0.000123447% change)
#     iteration   21: trace = 9.707583073044082 (0.000123771% change)
#     iteration   22: trace = 9.707571026044368 (0.000124099% change)
#     iteration   23: trace = 9.707558946843692 (0.000124431% change)
#     iteration   24: trace = 9.7075468349191 (0.000124768% change)
#     iteration   25: trace = 9.707534689647776 (0.000125112% change)
#     iteration   26: trace = 9.707522510312465 (0.000125463% change)
#     iteration   27: trace = 9.707510296106285 (0.000125822% change)
#     iteration   28: trace = 9.707498046137395 (0.000126191% change)
#     iteration   29: trace = 9.707485759433213 (0.000126569% change)
#     iteration   30: trace = 9.707473434944252 (0.000126959% change)
#     iteration   31: trace = 9.707461071547772 (0.00012736% change)
#     iteration   32: trace = 9.707448668050976 (0.000127773% change)
#     iteration   33: trace = 9.707436223193923 (0.000128199% change)
#     iteration   34: trace = 9.707423735651506 (0.000128639% change)
#     iteration   35: trace = 9.707411204038848 (0.000129093% change)
#     iteration   36: trace = 9.707398626908631 (0.000129562% change)
#     iteration   37: trace = 9.707386002756415 (0.000130047% change)
#     iteration   38: trace = 9.707373330021291 (0.000130547% change)
#     iteration   39: trace = 9.70736060708731 (0.000131065% change)
#     iteration   40: trace = 9.707347832284661 (0.000131599% change)
#     iteration   41: trace = 9.707335003890655 (0.000132151% change)
#     iteration   42: trace = 9.70732212013051 (0.000132722% change)
#     iteration   43: trace = 9.707309179177974 (0.000133311% change)
#     iteration   44: trace = 9.707296179155762 (0.00013392% change)
#     iteration   45: trace = 9.707283118135814 (0.000134549% change)
#     iteration   46: trace = 9.707269994139434 (0.000135198% change)
#     iteration   47: trace = 9.707256805137224 (0.000135867% change)
#     iteration   48: trace = 9.707243549048931 (0.000136559% change)
#     iteration   49: trace = 9.707230223743132 (0.000137272% change)
#     iteration   50: trace = 9.707216827036779 (0.000138008% change)
#     iteration   51: trace = 9.707203356694665 (0.000138766% change)
#     iteration   52: trace = 9.707189810428691 (0.000139549% change)
#     iteration   53: trace = 9.707176185897108 (0.000140355% change)
#     iteration   54: trace = 9.707162480703587 (0.000141186% change)
#     iteration   55: trace = 9.707148692396215 (0.000142043% change)
#     iteration   56: trace = 9.70713481846636 (0.000142925% change)
#     iteration   57: trace = 9.707120856347466 (0.000143834% change)
#     iteration   58: trace = 9.707106803413735 (0.000144769% change)
#     iteration   59: trace = 9.70709265697873 (0.000145733% change)
#     iteration   60: trace = 9.707078414293846 (0.000146725% change)
#     iteration   61: trace = 9.707064072546775 (0.000147745% change)
#     iteration   62: trace = 9.707049628859792 (0.000148796% change)
#     iteration   63: trace = 9.707035080288019 (0.000149876% change)
#     iteration   64: trace = 9.707020423817605 (0.000150988% change)
#     iteration   65: trace = 9.707005656363794 (0.000152132% change)
#     iteration   66: trace = 9.706990774768961 (0.000153308% change)
#     iteration   67: trace = 9.706975775800554 (0.000154517% change)
#     iteration   68: trace = 9.706960656148967 (0.000155761% change)
#     iteration   69: trace = 9.70694541242535 (0.000157039% change)
#     resetting CG direction...
#     large trace change predicted (2.02055%)
#     iteration   70: trace = 9.507396641654008 (2.07708% change)
#     iteration   71: trace = 9.433751628867618 (0.777619% change)
#     iteration   72: trace = 9.404694410911926 (0.308488% change)
#     iteration   73: trace = 9.395505535156204 (0.097753% change)
#     iteration   74: trace = 9.393767264147787 (0.0185028% change)
#     iteration   75: trace = 9.393535156816387 (0.0024709% change)
#     iteration   76: trace = 9.393486155693324 (0.000521649% change)
#     iteration   77: trace = 9.393467855655587 (0.000194816% change)
#     iteration   78: trace = 9.393466719467558 (1.20955e-05% change)
#     iteration   79: trace = 9.393466623289557 (1.02388e-06% change)
# Finished solving for bands 1 to 8 after 79 iterations.
# tmfreqs:, 43, 0.394737, 0.394737, 0, 0.558242, 0.519745, 0.635318, 0.718945, 0.803393, 1.26461, 1.30248, 1.43992, 1.4793
# elapsed time for k point: 0.22351288795471191
# solve_kpoint (0.368421,0.368421,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 9.252056339336026 (0.0622574% change)
#     iteration    2: trace = 9.251425210697498 (0.00682173% change)
#     iteration    3: trace = 9.251328436537309 (0.00104605% change)
#     iteration    4: trace = 9.251302308782471 (0.000282422% change)
#     iteration    5: trace = 9.251299309077442 (3.24247e-05% change)
#     iteration    6: trace = 9.251299050606946 (2.79388e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 44, 0.368421, 0.368421, 0, 0.521026, 0.486268, 0.642366, 0.727469, 0.835125, 1.24483, 1.29936, 1.40802, 1.46802
# elapsed time for k point: 0.023607969284057617
# solve_kpoint (0.342105,0.342105,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 9.118737228984646 (0.0481609% change)
#     iteration    2: trace = 9.118291407720141 (0.00488919% change)
#     iteration    3: trace = 9.118236876446932 (0.000598044% change)
#     iteration    4: trace = 9.118225329057843 (0.000126641% change)
#     iteration    5: trace = 9.11822403262396 (1.42181e-05% change)
#     iteration    6: trace = 9.11822386905482 (1.79387e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 45, 0.342105, 0.342105, 0, 0.48381, 0.45234, 0.65082, 0.737754, 0.86679, 1.22363, 1.29613, 1.37632, 1.45704
# elapsed time for k point: 0.025343656539916992
# solve_kpoint (0.315789,0.315789,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 8.997088659478283 (0.0385782% change)
#     iteration    2: trace = 8.996759459176499 (0.00365903% change)
#     iteration    3: trace = 8.996724880293096 (0.000384349% change)
#     iteration    4: trace = 8.996719251664214 (6.25631e-05% change)
#     iteration    5: trace = 8.996718704958779 (6.07672e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 46, 0.315789, 0.315789, 0, 0.446594, 0.418123, 0.660587, 0.749725, 0.898129, 1.20155, 1.29303, 1.34483, 1.44658
# elapsed time for k point: 0.018337488174438477
# solve_kpoint (0.289474,0.289474,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 8.888737070391626 (0.0319105% change)
#     iteration    2: trace = 8.888485021447288 (0.00283564% change)
#     iteration    3: trace = 8.888461371609067 (0.000266073% change)
#     iteration    4: trace = 8.888458373829719 (3.37266e-05% change)
#     iteration    5: trace = 8.888458126231615 (2.78561e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 47, 0.289474, 0.289474, 0, 0.409378, 0.383706, 0.671557, 0.763305, 0.928919, 1.17896, 1.29036, 1.31359, 1.43673
# elapsed time for k point: 0.027028322219848633
# solve_kpoint (0.263158,0.263158,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 8.794819876047697 (0.0272134% change)
#     iteration    2: trace = 8.79462012959069 (0.00227121% change)
#     iteration    3: trace = 8.794603243086062 (0.00019201% change)
#     iteration    4: trace = 8.794601584671373 (1.88572e-05% change)
#     iteration    5: trace = 8.794601448860234 (1.54426e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 48, 0.263158, 0.263158, 0, 0.372161, 0.349143, 0.683602, 0.778406, 0.958924, 1.15618, 1.28263, 1.28842, 1.42759
# elapsed time for k point: 0.020003318786621094
# solve_kpoint (0.236842,0.236842,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 8.71613574244825 (0.0239071% change)
#     iteration    2: trace = 8.715970972786916 (0.00189042% change)
#     iteration    3: trace = 8.715958219585177 (0.00014632% change)
#     iteration    4: trace = 8.715957331400816 (1.01903e-05% change)
#     iteration    5: trace = 8.715957251709241 (9.14318e-07% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 49, 0.236842, 0.236842, 0, 0.334945, 0.314467, 0.696573, 0.794943, 0.987855, 1.13343, 1.25198, 1.28756, 1.4192
# elapsed time for k point: 0.018441438674926758
# solve_kpoint (0.210526,0.210526,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 8.65323502216042 (0.0216352% change)
#     iteration    2: trace = 8.653091769360794 (0.0016555% change)
#     iteration    3: trace = 8.65308110109874 (0.000123289% change)
#     iteration    4: trace = 8.653080620075983 (5.55898e-06% change)
# Finished solving for bands 1 to 8 after 4 iterations.
# tmfreqs:, 50, 0.210526, 0.210526, 0, 0.297729, 0.279703, 0.710294, 0.812827, 1.01535, 1.11096, 1.22165, 1.28817, 1.41161
# elapsed time for k point: 0.0195925235748291
# solve_kpoint (0.184211,0.184211,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 8.606474271707174 (0.0201836% change)
#     iteration    2: trace = 8.606340716406816 (0.00155181% change)
#     iteration    3: trace = 8.6063300471637 (0.00012397% change)
#     iteration    4: trace = 8.606329599095302 (5.20627e-06% change)
# Finished solving for bands 1 to 8 after 4 iterations.
# tmfreqs:, 51, 0.184211, 0.184211, 0, 0.260513, 0.244869, 0.724547, 0.83197, 1.04094, 1.089, 1.19168, 1.29074, 1.40486
# elapsed time for k point: 0.019377470016479492
# solve_kpoint (0.157895,0.157895,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 8.576045561169103 (0.0194358% change)
#     iteration    2: trace = 8.575909290831978 (0.00158898% change)
#     iteration    3: trace = 8.575895963691019 (0.000155402% change)
#     iteration    4: trace = 8.575894962335926 (1.16764e-05% change)
#     iteration    5: trace = 8.575894814239444 (1.72689e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 52, 0.157895, 0.157895, 0, 0.223297, 0.20998, 0.739056, 0.852285, 1.06409, 1.06784, 1.1621, 1.2958, 1.39895
# elapsed time for k point: 0.02390265464782715
# solve_kpoint (0.131579,0.131579,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 8.561982618335019 (0.0193465% change)
#     iteration    2: trace = 8.56182931823183 (0.00179049% change)
#     iteration    3: trace = 8.561809423114227 (0.00023237% change)
#     iteration    4: trace = 8.561806717989892 (3.15952e-05% change)
#     iteration    5: trace = 8.561806422764402 (3.44817e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 53, 0.131579, 0.131579, 0, 0.186081, 0.175045, 0.753453, 0.873688, 1.04783, 1.08419, 1.13295, 1.30389, 1.39393
# elapsed time for k point: 0.027759790420532227
# solve_kpoint (0.105263,0.105263,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 8.564147690317803 (0.0199664% change)
#     iteration    2: trace = 8.56395577008759 (0.002241% change)
#     iteration    3: trace = 8.563920876668407 (0.000407446% change)
#     iteration    4: trace = 8.563913637084397 (8.45359e-05% change)
#     iteration    5: trace = 8.563913140775236 (5.79535e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 54, 0.105263, 0.105263, 0, 0.148865, 0.140076, 0.767236, 0.896096, 1.02948, 1.10072, 1.10426, 1.31541, 1.38979
# elapsed time for k point: 0.022615909576416016
# solve_kpoint (0.0789474,0.0789474,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 8.582168327685613 (0.0214679% change)
#     iteration    2: trace = 8.58189873046679 (0.00314141% change)
#     iteration    3: trace = 8.581827082971193 (0.000834871% change)
#     iteration    4: trace = 8.58180634212928 (0.000241684% change)
#     iteration    5: trace = 8.581805370029224 (1.13275e-05% change)
#     iteration    6: trace = 8.581805357833348 (1.42113e-07% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 55, 0.0789474, 0.0789474, 0, 0.111648, 0.105079, 0.779706, 0.919426, 1.01347, 1.07609, 1.1134, 1.33048, 1.38657
# elapsed time for k point: 0.023738622665405273
# solve_kpoint (0.0526316,0.0526316,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 8.615253186746569 (0.0243619% change)
#     iteration    2: trace = 8.614808925055613 (0.00515682% change)
#     iteration    3: trace = 8.61461859942948 (0.00220931% change)
#     iteration    4: trace = 8.614545098755924 (0.000853212% change)
#     iteration    5: trace = 8.614542270979157 (3.28256e-05% change)
#     iteration    6: trace = 8.614542173826273 (1.12778e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 56, 0.0526316, 0.0526316, 0, 0.0744323, 0.0700636, 0.789921, 0.943582, 1.00074, 1.04849, 1.12221, 1.3487, 1.38425
# elapsed time for k point: 0.023698091506958008
# solve_kpoint (0.0263158,0.0263158,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 8.661425060680303 (0.0306939% change)
#     iteration    2: trace = 8.660397244226569 (0.0118673% change)
#     iteration    3: trace = 8.659551070487 (0.00977109% change)
#     iteration    4: trace = 8.659159046169719 (0.00452718% change)
#     iteration    5: trace = 8.659145618170845 (0.000155073% change)
#     iteration    6: trace = 8.659144478028983 (1.31669e-05% change)
#     iteration    7: trace = 8.659144364183909 (1.31474e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 57, 0.0263158, 0.0263158, 0, 0.0372161, 0.0350349, 0.796754, 0.968372, 0.992399, 1.02165, 1.12734, 1.36877, 1.38286
# elapsed time for k point: 0.025829553604125977
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     iteration    1: trace = 8.71172046006353 (0.0562786% change)
#     iteration    2: trace = 8.705412918957894 (0.0724292% change)
#     iteration    3: trace = 8.696399126841985 (0.103596% change)
#     iteration    4: trace = 8.693339858991617 (0.0351847% change)
#     iteration    5: trace = 8.693267030925316 (0.000837749% change)
#     iteration    6: trace = 8.693260663365265 (7.32471e-05% change)
#     iteration    7: trace = 8.693260298030442 (4.20251e-06% change)
# Finished solving for bands 2 to 8 after 7 iterations.
# tmfreqs:, 58, 0, 0, 0, 0, 0, 0.799176, 0.989474, 0.989475, 0.999859, 1.12902, 1.3824, 1.3824
# elapsed time for k point: 0.0268557071685791
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.6224920718175437 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.4673658092763464 at Vector3<0.5, 0.0, 0.0> to 0.7991758799067625 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.7035347133508743 at Vector3<0.5, 0.5, 0.0> to 0.9894744395139274 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.703534713351152 at Vector3<0.5, 0.5, 0.0> to 1.0640881040505417 at Vector3<0.1578947368421053, 0.1578947368421053, 0.0>
# Band 5 range: 0.9998587372049046 at Vector3<0.0, 0.0, 0.0> to 1.309217525400028 at Vector3<0.5, 0.5, 0.0>
# Band 6 range: 1.1042615095197814 at Vector3<0.10526315789473684, 0.10526315789473684, 0.0> to 1.3092175254414213 at Vector3<0.5, 0.5, 0.0>
# Band 7 range: 1.2276881883525266 at Vector3<0.2631578947368421, 0.0, 0.0> to 1.5123190887881344 at Vector3<0.5, 0.5, 0.0>
# Band 8 range: 1.3823992761391661 at Vector3<0.0, 0.0, 0.0> to 1.5383122269436258 at Vector3<0.42105263157894735, 0.42105263157894735, 0.0>
# total elapsed time for run: 1.7380149364471436
# done
# ['moire_pipeline_outputs/04_bands_AA_1x.png',
#  'moire_pipeline_outputs/04_bands_AA_2x.png',
#  'moire_pipeline_outputs/04_bands_AA_3x.png',
#  'moire_pipeline_outputs/04_bands_AB_1x.png',
#  'moire_pipeline_outputs/04_bands_AB_2x.png',
#  'moire_pipeline_outputs/04_bands_AB_3x.png',
#  'moire_pipeline_outputs/04_bands_BA_1x.png',
#  'moire_pipeline_outputs/04_bands_BA_2x.png',
#  'moire_pipeline_outputs/04_bands_BA_3x.png']

# %% [markdown]
# ### Collate the 9 band plots into a 3×3 montage image

# %%
def make_montage(images: List[str], rows: int, cols: int, outfile: str, pad: int = 10, bg=255):
    assert len(images) == rows*cols
    ims = [Image.open(p).convert("RGB") for p in images]
    w, h = ims[0].size
    W = cols*w + (cols+1)*pad
    H = rows*h + (rows+1)*pad
    canvas = Image.new("RGB", (W,H), (bg,bg,bg))
    idx = 0
    for r in range(rows):
        for c in range(cols):
            x = pad + c*(w+pad); y = pad + r*(h+pad)
            canvas.paste(ims[idx], (x,y)); idx += 1
    canvas.save(outfile)
    return outfile

# Order: rows = AA/AB/BA, cols = 1x/2x/3x
grid_order = []
for reg in ["AA","AB","BA"]:
    for sc in [1,2,3]:
        grid_order.append(os.path.join(output_dir, f"04_bands_{reg}_{sc}x.png"))

montage_path = os.path.join(output_dir, "05_moire_bands_montage_3x3.png")
make_montage(grid_order, rows=3, cols=3, outfile=montage_path)
montage_path
# Out:
# 'moire_pipeline_outputs/05_moire_bands_montage_3x3.png'

# %% [markdown]
# ## 6) Optimize moiré angle and produce final AA/AB/BA band diagrams

# %%
# Envelope model helpers: monolayer mass, registry edges, potential, solver

from typing import Dict, Tuple

def monolayer_geometry():
    lat = mp_lattice_from_vectors(cand.a1, cand.a2)
    # Single air hole at (0,0) in dielectric background
    geom = [mp.Cylinder(radius=cand.hole_radius_a, material=mp.air, center=mp.Vector3(0,0,0))]
    mat = mp.Medium(epsilon=cand.eps_bg)
    return lat, geom, mat


def k0_from_label(lattice_type: str, k_label: str):
    kpts, labels, inds = hs_path_for_lattice(lattice_type, kpts_per_seg)
    if k_label in labels:
        idx = labels.index(k_label)
        kp = kpts[inds[idx]]
        return kp
    # Fallback to Gamma
    return mp.Vector3(0, 0)


def run_mpb_single_k(lat, geom, mat, kpoint, num_bands, pol: str):
    ms = mpb.ModeSolver(geometry_lattice=lat, geometry=geom, default_material=mat,
                        k_points=[kpoint], resolution=resolution, num_bands=num_bands, dimensions=2)
    pol = pol.strip().lower()
    if pol == "tm":
        ms.run_tm(); freqs = np.array(ms.all_freqs)[0]
    elif pol == "te":
        ms.run_te(); freqs = np.array(ms.all_freqs)[0]
    else:
        ms.run_tm(); freqs = np.array(ms.all_freqs)[0]
    return freqs


def monolayer_band_edge_and_curvature(delta: float = 0.02) -> Tuple[float, mp.Vector3, float]:
    """
    Returns (omega0, k0, alpha), where alpha is the curvature coefficient used in
    the envelope operator as -alpha * ∇^2. We approximate isotropic alpha from
    second derivatives along fractional kx and ky directions.
    """
    lat, geom, mat = monolayer_geometry()
    k0 = k0_from_label(cand.lattice_type, cand.k_label)
    # Offsets in fractional coordinates
    ex = mp.Vector3(1.0, 0.0)
    ey = mp.Vector3(0.0, 1.0)
    kx_p = k0 + delta * ex
    kx_m = k0 - delta * ex
    ky_p = k0 + delta * ey
    ky_m = k0 - delta * ey
    # Frequencies at points
    f0 = run_mpb_single_k(lat, geom, mat, k0, num_bands, cand.polarization)[cand.band_index]
    fxp = run_mpb_single_k(lat, geom, mat, kx_p, num_bands, cand.polarization)[cand.band_index]
    fxm = run_mpb_single_k(lat, geom, mat, kx_m, num_bands, cand.polarization)[cand.band_index]
    fyp = run_mpb_single_k(lat, geom, mat, ky_p, num_bands, cand.polarization)[cand.band_index]
    fym = run_mpb_single_k(lat, geom, mat, ky_m, num_bands, cand.polarization)[cand.band_index]
    # Second derivatives (central)
    d2x = (fxp + fxm - 2*f0) / (delta**2)
    d2y = (fyp + fym - 2*f0) / (delta**2)
    alpha = 0.5 * (d2x + d2y)
    return f0, k0, alpha


def registry_edge_frequencies(k0) -> Dict[str, float]:
    """Compute registry band-edge frequencies at the same k0 for AA/AB/BA using the small-cell registry geometries."""
    edges: Dict[str, float] = {}
    for reg in ["AA", "AB", "BA"]:
        lat = mp_lattice_from_vectors(cand.a1, cand.a2)
        # reuse registry geometry builder on base (L1) cell
        lat_r, geom_r, mat_r = mpb_geometry_for_registry(reg, cand.a1, cand.a2, cand.hole_radius_a, cand.eps_bg)
        # Force lattice from cand vectors to align sizes
        ms = mpb.ModeSolver(geometry_lattice=lat, geometry=geom_r, default_material=mat_r,
                            k_points=[k0], resolution=resolution, num_bands=num_bands, dimensions=2)
        pol = cand.polarization.strip().lower()
        if pol == "tm":
            ms.run_tm(); freqs = np.array(ms.all_freqs)[0]
        elif pol == "te":
            ms.run_te(); freqs = np.array(ms.all_freqs)[0]
        else:
            ms.run_tm(); freqs = np.array(ms.all_freqs)[0]
        edges[reg] = freqs[cand.band_index]
    return edges


def moire_vectors(theta_deg: float) -> Tuple[np.ndarray, np.ndarray, object]:
    """Return moiré L1,L2 (2D) and moire object for stacking queries."""
    if not ML_AVAILABLE:
        L1m, L2m = get_moire_vectors_from_framework(cand.a1, cand.a2, theta_deg)
        return L1m, L2m, None
    base = ml.create_square_lattice(1.0)
    moire = ml.py_twisted_bilayer(base, math.radians(theta_deg))
    (v1, v2) = moire.primitive_vectors()
    L1m = np.array([v1[0], v1[1]], float)
    L2m = np.array([v2[0], v2[1]], float)
    return L1m, L2m, moire


def stacking_type_at(moire_obj, pos_xy: Tuple[float, float]) -> str:
    if moire_obj is None:
        # Fallback: simple proximity classification in fractional coords
        return "AA"
    st = moire_obj.get_stacking_at([pos_xy[0], pos_xy[1], 0.0])
    if st is None:
        return "AA"
    s = str(st).upper()
    if s in ("AA", "AB", "BA"):
        return s
    if s == "A":
        return "AB"
    if s == "B":
        return "BA"
    return "AA"


def build_moire_potential(theta_deg: float, edges: Dict[str, float], omega0: float, N: int = 64) -> Tuple[np.ndarray, np.ndarray, np.ndarray, object]:
    """Return (U,V, Vgrid, moire_obj) where U,V are grids in [0,1), Vgrid is potential array shape (N,N)."""
    L1m, L2m, moire_obj = moire_vectors(theta_deg)
    U = np.linspace(0.0, 1.0, N, endpoint=False)
    V = np.linspace(0.0, 1.0, N, endpoint=False)
    Vgrid = np.zeros((N, N), float)
    for i, u in enumerate(U):
        for j, v in enumerate(V):
            pos = u * L1m + v * L2m
            reg = stacking_type_at(moire_obj, (pos[0], pos[1]))
            Vgrid[i, j] = edges.get(reg, edges["AA"]) - omega0
    return U, V, Vgrid, moire_obj


def solve_envelope(Vgrid: np.ndarray, alpha: float, bc: str = "dirichlet") -> Tuple[float, np.ndarray]:
    """Solve (-alpha ∇^2 + V) F = lambda F on a unit-square grid using FD.
    Returns (lambda0, F0) for the ground state.
    """
    n = Vgrid.shape[0]
    N = n * n
    h = 1.0 / n
    try:
        import scipy.sparse as sp
        import scipy.sparse.linalg as spla
    except Exception as e:
        print("SciPy not available for sparse solve, using dense fallback (n<=48 recommended):", e)
        # Dense fallback with 5-point Laplacian scaled by 1/h^2
        def idx(i, j): return i*n + j
        L = np.zeros((N, N), float)
        for i in range(n):
            for j in range(n):
                k = idx(i, j)
                L[k, k] = 4.0
                for (ii, jj) in ((i-1,j),(i+1,j),(i,j-1),(i,j+1)):
                    if 0 <= ii < n and 0 <= jj < n:
                        L[k, idx(ii, jj)] = -1.0
        L *= (1.0 / (h*h))
        H = alpha * L + np.diag(Vgrid.reshape(N))
        w, v = np.linalg.eigh(H)
        return float(w[0]), v[:, 0].reshape(n, n)

    # Sparse path
    main = np.full(N, 4.0)
    off1 = np.full(N-1, -1.0)
    offn = np.full(N-n, -1.0)
    for k in range(1, n):
        off1[k*n - 1] = 0.0  # block boundaries
    diags = [main, off1, off1, offn, offn]
    offsets = [0, -1, 1, -n, n]
    L = sp.diags(diags, offsets, shape=(N, N), format='csr')
    L = L * (1.0 / (h*h))
    H = alpha * L + sp.diags(Vgrid.reshape(N), 0, format='csr')
    vals, vecs = spla.eigsh(H, k=1, which='SA')
    F0 = vecs[:, 0].reshape(n, n)
    return float(vals[0]), F0


def objective_for_theta(theta_deg: float, omega0: float, alpha: float, edges: Dict[str, float], N: int = 64) -> Tuple[float, float]:
    U, V, Vgrid, _ = build_moire_potential(theta_deg, edges, omega0, N)
    lam0, _ = solve_envelope(Vgrid, alpha)
    # Also compute potential contrast for reference
    contrast = float(Vgrid.max() - Vgrid.min())
    return lam0, contrast

# %%
# Angle optimization and final outputs

# 1) Monolayer curvature and edge at k0
if not MEEP_AVAILABLE:
    raise RuntimeError("Meep/MPB not available; cannot run envelope optimization.")

omega0, k0, alpha = monolayer_band_edge_and_curvature(delta=0.02)
print(f"Monolayer target band edge ω0={omega0:.6f} at k0=({k0.x:.3f},{k0.y:.3f}), alpha={alpha:.6e}")

# 2) Registry band-edge shifts at same k0
edges = registry_edge_frequencies(k0)
print("Registry edges at k0:", {k: f"{v:.6f}" for k, v in edges.items()})

# 3) Angle scan and objective (ground-state envelope eigenvalue)
angle_range = np.linspace(0.5, 5.0, 19)  # degrees
objs = []
contrasts = []
for th in angle_range:
    lam0, contrast = objective_for_theta(th, omega0, alpha, edges, N=64)
    objs.append(lam0); contrasts.append(contrast)

objs = np.array(objs); contrasts = np.array(contrasts)
opt_idx = int(np.argmin(objs))
opt_theta = float(angle_range[opt_idx])
print(f"Optimal angle ≈ {opt_theta:.3f}° (min envelope eigenvalue {objs[opt_idx]:.6f})")

# 4) Plot objective and contrast vs angle
plt.figure(figsize=(6,4))
plt.plot(angle_range, objs, '-o', ms=3)
plt.xlabel('Twist angle (deg)'); plt.ylabel('Ground-state λ')
plt.title('Envelope objective vs angle')
plt.tight_layout(); plt.savefig(os.path.join(output_dir, '06_objective_vs_angle.png'), dpi=160); plt.close()

plt.figure(figsize=(6,4))
plt.plot(angle_range, contrasts, '-o', ms=3)
plt.xlabel('Twist angle (deg)'); plt.ylabel('Potential contrast (ω units)')
plt.title('Moiré potential contrast vs angle')
plt.tight_layout(); plt.savefig(os.path.join(output_dir, '06_contrast_vs_angle.png'), dpi=160); plt.close()

# 5) Build and plot final moiré lattice (direct and reciprocal)
L1m, L2m, moire_obj = moire_vectors(opt_theta)

# Direct space plot
plt.figure(figsize=(6,6))
cell = np.array([[0,0], L1m, L1m+L2m, L2m, [0,0]], float)
plt.plot(cell[:,0], cell[:,1], 'k-', lw=2)
for m in (-1,0,1):
    for n in (-1,0,1):
        if m==0 and n==0: continue
        t = m*L1m + n*L2m
        shell = cell + t
        plt.plot(shell[:,0], shell[:,1], color='0.75', lw=1)
plt.gca().set_aspect('equal','box')
plt.title(f"Final moiré lattice (direct) @ {opt_theta:.3f}°")
plt.tight_layout(); plt.savefig(os.path.join(output_dir, '07_final_moire_direct.png'), dpi=160); plt.close()

# Reciprocal space plot
if ML_AVAILABLE and moire_obj is not None:
    L1_py, L2_py = moire_obj.lattice_1(), moire_obj.lattice_2()
    try:
        ax = plot_reciprocal_registry(L1_py, L2_py, factor=1)
        ax.figure.savefig(os.path.join(output_dir, '07_final_moire_reciprocal.png'), dpi=160)
        plt.close(ax.figure)
    except Exception as e:
        print("Reciprocal plotting failed:", e)

# 6) Band diagrams for x1 mini unit cells (AA/AB/BA)
# Use moiré vectors at optimal angle for geometry scaling
L1_opt, L2_opt = L1m, L2m

final_band_plots = []
for reg in ["AA", "AB", "BA"]:
    outp = os.path.join(output_dir, f"08_final_bands_{reg}_1x")
    png = run_bands_for_cell(reg, L1_opt, L2_opt, cand.lattice_type, cand.band_index, cand.k_label, outp)
    final_band_plots.append(png)

final_band_plots
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 40 x 40 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.5, 0.0>
# elapsed time for initialization: 0.012264251708984375
# solve_kpoint (0.5,0.5,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 1 to 8...
#     near maximum in trace
#     iteration    1: trace = 15.32104583144288 (195.424% change)
#     iteration    2: trace = 5.132212364514421 (99.6304% change)
#     iteration    3: trace = 4.363256005762544 (16.1963% change)
#     iteration    4: trace = 4.27063369784981 (2.14555% change)
#     iteration    5: trace = 4.257759404327594 (0.301916% change)
#     iteration    6: trace = 4.255845548607867 (0.0449599% change)
#     iteration    7: trace = 4.255689237553896 (0.00367292% change)
#     iteration    8: trace = 4.255668449108257 (0.000488487% change)
#     iteration    9: trace = 4.25566562805901 (6.62892e-05% change)
#     iteration   10: trace = 4.255665260566307 (8.63538e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 1, 0.5, 0.5, 0, 0.707107, 0.379669, 0.455506, 0.455506, 0.657335, 0.859022, 0.902277, 0.902278, 0.947802
# elapsed time for k point: 0.03295278549194336
# total elapsed time for run: 0.045356035232543945
# done
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 40 x 40 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.52, 0.5, 0.0>
# elapsed time for initialization: 0.016150236129760742
# solve_kpoint (0.52,0.5,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 1 to 8...
#     near maximum in trace
#     iteration    1: trace = 15.3460074910048 (195.418% change)
#     iteration    2: trace = 5.14419367012917 (99.5775% change)
#     iteration    3: trace = 4.363357967699492 (16.4256% change)
#     iteration    4: trace = 4.270931333993762 (2.14092% change)
#     iteration    5: trace = 4.258646531574517 (0.288052% change)
#     iteration    6: trace = 4.256679554188683 (0.0461985% change)
#     iteration    7: trace = 4.256502888865324 (0.00415039% change)
#     iteration    8: trace = 4.25647919869075 (0.000556566% change)
#     iteration    9: trace = 4.256476125700285 (7.21956e-05% change)
#     iteration   10: trace = 4.256475726628848 (9.37563e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 1, 0.52, 0.5, 0, 0.721388, 0.378882, 0.455021, 0.456441, 0.658011, 0.857879, 0.902263, 0.902404, 0.948787
# elapsed time for k point: 0.04273509979248047
# total elapsed time for run: 0.05904841423034668
# done
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 40 x 40 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.48, 0.5, 0.0>
# elapsed time for initialization: 0.01332402229309082
# solve_kpoint (0.48,0.5,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 1 to 8...
#     near maximum in trace
#     iteration    1: trace = 15.29702869470943 (195.431% change)
#     iteration    2: trace = 5.121676605833117 (99.667% change)
#     iteration    3: trace = 4.365705051097001 (15.9364% change)
#     iteration    4: trace = 4.272391996530004 (2.1605% change)
#     iteration    5: trace = 4.258635883509053 (0.322496% change)
#     iteration    6: trace = 4.256663214884277 (0.0463323% change)
#     iteration    7: trace = 4.256501941631077 (0.0037888% change)
#     iteration    8: trace = 4.256479309781547 (0.000531702% change)
#     iteration    9: trace = 4.256476112168626 (7.51235e-05% change)
#     iteration   10: trace = 4.256475718803002 (9.24158e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 1, 0.48, 0.5, 0, 0.693109, 0.378882, 0.455021, 0.456441, 0.658011, 0.857879, 0.902263, 0.902404, 0.948787
# elapsed time for k point: 0.044808387756347656
# total elapsed time for run: 0.05832362174987793
# done
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 40 x 40 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.52, 0.0>
# elapsed time for initialization: 0.013631820678710938
# solve_kpoint (0.5,0.52,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 1 to 8...
#     near maximum in trace
#     iteration    1: trace = 15.31903328487935 (195.426% change)
#     iteration    2: trace = 5.123755405767118 (99.7445% change)
#     iteration    3: trace = 4.359969000032149 (16.1073% change)
#     iteration    4: trace = 4.270551912899222 (2.07211% change)
#     iteration    5: trace = 4.25854381809167 (0.28158% change)
#     iteration    6: trace = 4.256667341093607 (0.0440735% change)
#     iteration    7: trace = 4.256501570062391 (0.00389446% change)
#     iteration    8: trace = 4.256479092578481 (0.000528076% change)
#     iteration    9: trace = 4.256476096286769 (7.03937e-05% change)
#     iteration   10: trace = 4.256475726746818 (8.68183e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 1, 0.5, 0.52, 0, 0.721388, 0.378882, 0.455021, 0.456442, 0.658011, 0.857879, 0.902262, 0.902405, 0.948787
# elapsed time for k point: 0.040605783462524414
# total elapsed time for run: 0.054387807846069336
# done
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 40 x 40 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.48, 0.0>
# elapsed time for initialization: 0.012763261795043945
# solve_kpoint (0.5,0.48,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 1 to 8...
#     near maximum in trace
#     iteration    1: trace = 15.32598560962784 (195.422% change)
#     iteration    2: trace = 5.142420405179773 (99.5052% change)
#     iteration    3: trace = 4.36885496840042 (16.2663% change)
#     iteration    4: trace = 4.272666835596911 (2.22619% change)
#     iteration    5: trace = 4.258694167330328 (0.32756% change)
#     iteration    6: trace = 4.25666308267532 (0.047704% change)
#     iteration    7: trace = 4.256501411324036 (0.00379815% change)
#     iteration    8: trace = 4.256479253189377 (0.000520573% change)
#     iteration    9: trace = 4.256476138829911 (7.31675e-05% change)
#     iteration   10: trace = 4.256475718408689 (9.87721e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 1, 0.5, 0.48, 0, 0.693109, 0.378882, 0.455021, 0.456442, 0.658011, 0.857879, 0.902262, 0.902405, 0.948787
# elapsed time for k point: 0.03501415252685547
# total elapsed time for run: 0.04790830612182617
# done
# Monolayer target band edge ω0=0.657335 at k0=(0.500,0.500), alpha=3.377614e+00
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 40 x 40 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.5, 0.0>
# elapsed time for initialization: 0.02016448974609375
# solve_kpoint (0.5,0.5,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 1 to 8...
#     near maximum in trace
#     iteration    1: trace = 15.32104583144288 (195.424% change)
#     iteration    2: trace = 5.132212364514421 (99.6304% change)
#     iteration    3: trace = 4.363256005762544 (16.1963% change)
#     iteration    4: trace = 4.27063369784981 (2.14555% change)
#     iteration    5: trace = 4.257759404327594 (0.301916% change)
#     iteration    6: trace = 4.255845548607867 (0.0449599% change)
#     iteration    7: trace = 4.255689237553896 (0.00367292% change)
#     iteration    8: trace = 4.255668449108257 (0.000488487% change)
#     iteration    9: trace = 4.25566562805901 (6.62892e-05% change)
#     iteration   10: trace = 4.255665260566307 (8.63538e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 1, 0.5, 0.5, 0, 0.707107, 0.379669, 0.455506, 0.455506, 0.657335, 0.859022, 0.902277, 0.902278, 0.947802
# elapsed time for k point: 0.0516204833984375
# total elapsed time for run: 0.07198500633239746
# done
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 40 x 40 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.5,0.5,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.5, 0.0>
# elapsed time for initialization: 0.016247987747192383
# solve_kpoint (0.5,0.5,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 1 to 8...
#     near maximum in trace
#     iteration    1: trace = 30.22571269907184 (194.254% change)
#     iteration    2: trace = 11.46587336334737 (89.9934% change)
#     iteration    3: trace = 10.21759663541697 (11.5136% change)
#     iteration    4: trace = 9.984608222658274 (2.30656% change)
#     iteration    5: trace = 9.922325316841425 (0.625741% change)
#     iteration    6: trace = 9.870614255248121 (0.52252% change)
#     iteration    7: trace = 9.801804933794994 (0.699551% change)
#     iteration    8: trace = 9.779069628463446 (0.23222% change)
#     iteration    9: trace = 9.773527569491042 (0.0566887% change)
#     iteration   10: trace = 9.770850654440579 (0.0273932% change)
#     iteration   11: trace = 9.767903768404281 (0.0301645% change)
#     iteration   12: trace = 9.767413016145271 (0.00502426% change)
#     iteration   13: trace = 9.767313105242113 (0.00102291% change)
#     iteration   14: trace = 9.767279063983501 (0.000348523% change)
#     iteration   15: trace = 9.767247656049452 (0.000321563% change)
#     iteration   16: trace = 9.767236618977993 (0.000113001% change)
#     iteration   17: trace = 9.767235345300392 (1.30403e-05% change)
#     iteration   18: trace = 9.767234769925123 (5.89087e-06% change)
# Finished solving for bands 1 to 8 after 18 iterations.
# tmfreqs:, 1, 0.5, 0.5, 0, 0.707107, 0.622492, 0.622492, 0.703535, 0.703535, 1.30922, 1.30922, 1.51232, 1.51232
# elapsed time for k point: 0.06428956985473633
# total elapsed time for run: 0.08072972297668457
# done
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 40 x 40 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.5,0.5,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.5, 0.0>
# elapsed time for initialization: 0.015599250793457031
# solve_kpoint (0.5,0.5,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 1 to 8...
#     near maximum in trace
#     iteration    1: trace = 30.22571269907184 (194.254% change)
#     iteration    2: trace = 11.46587336334737 (89.9934% change)
#     iteration    3: trace = 10.21759663541697 (11.5136% change)
#     iteration    4: trace = 9.984608222658274 (2.30656% change)
#     iteration    5: trace = 9.922325316841425 (0.625741% change)
#     iteration    6: trace = 9.870614255248121 (0.52252% change)
#     iteration    7: trace = 9.801804933794994 (0.699551% change)
#     iteration    8: trace = 9.779069628463446 (0.23222% change)
#     iteration    9: trace = 9.773527569491042 (0.0566887% change)
#     iteration   10: trace = 9.770850654440579 (0.0273932% change)
#     iteration   11: trace = 9.767903768404281 (0.0301645% change)
#     iteration   12: trace = 9.767413016145271 (0.00502426% change)
#     iteration   13: trace = 9.767313105242113 (0.00102291% change)
#     iteration   14: trace = 9.767279063983501 (0.000348523% change)
#     iteration   15: trace = 9.767247656049452 (0.000321563% change)
#     iteration   16: trace = 9.767236618977993 (0.000113001% change)
#     iteration   17: trace = 9.767235345300392 (1.30403e-05% change)
#     iteration   18: trace = 9.767234769925123 (5.89087e-06% change)
# Finished solving for bands 1 to 8 after 18 iterations.
# tmfreqs:, 1, 0.5, 0.5, 0, 0.707107, 0.622492, 0.622492, 0.703535, 0.703535, 1.30922, 1.30922, 1.51232, 1.51232
# elapsed time for k point: 0.06576895713806152
# total elapsed time for run: 0.08152556419372559
# done
# Registry edges at k0: {'AA': '0.657335', 'AB': '0.703535', 'BA': '0.703535'}
# Optimal angle ≈ 0.500° (min envelope eigenvalue 64.623200)
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 40 x 40 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (-0.00436331, 0.99999, 0)
#      (-0.99999, -0.00436331, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (-0.00436331, 0.99999, 0)
#      (-0.99999, -0.00436331, 0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,0,0)
#           radius 0.43, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 58 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.02631578947368421, 0.0, 0.0>
#   Vector3<0.05263157894736842, 0.0, 0.0>
#   Vector3<0.07894736842105263, 0.0, 0.0>
#   Vector3<0.10526315789473684, 0.0, 0.0>
#   Vector3<0.13157894736842105, 0.0, 0.0>
#   Vector3<0.15789473684210525, 0.0, 0.0>
#   Vector3<0.18421052631578946, 0.0, 0.0>
#   Vector3<0.21052631578947367, 0.0, 0.0>
#   Vector3<0.23684210526315788, 0.0, 0.0>
#   Vector3<0.2631578947368421, 0.0, 0.0>
#   Vector3<0.2894736842105263, 0.0, 0.0>
#   Vector3<0.3157894736842105, 0.0, 0.0>
#   Vector3<0.3421052631578947, 0.0, 0.0>
#   Vector3<0.3684210526315789, 0.0, 0.0>
#   Vector3<0.39473684210526316, 0.0, 0.0>
#   Vector3<0.42105263157894735, 0.0, 0.0>
#   Vector3<0.4473684210526315, 0.0, 0.0>
#   Vector3<0.47368421052631576, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.02631578947368421, 0.0>
#   Vector3<0.5, 0.05263157894736842, 0.0>
#   Vector3<0.5, 0.07894736842105263, 0.0>
#   Vector3<0.5, 0.10526315789473684, 0.0>
#   Vector3<0.5, 0.13157894736842105, 0.0>
#   Vector3<0.5, 0.15789473684210525, 0.0>
#   Vector3<0.5, 0.18421052631578946, 0.0>
#   Vector3<0.5, 0.21052631578947367, 0.0>
#   Vector3<0.5, 0.23684210526315788, 0.0>
#   Vector3<0.5, 0.2631578947368421, 0.0>
#   Vector3<0.5, 0.2894736842105263, 0.0>
#   Vector3<0.5, 0.3157894736842105, 0.0>
#   Vector3<0.5, 0.3421052631578947, 0.0>
#   Vector3<0.5, 0.3684210526315789, 0.0>
#   Vector3<0.5, 0.39473684210526316, 0.0>
#   Vector3<0.5, 0.42105263157894735, 0.0>
#   Vector3<0.5, 0.4473684210526315, 0.0>
#   Vector3<0.5, 0.47368421052631576, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4736842105263158, 0.4736842105263158, 0.0>
#   Vector3<0.4473684210526316, 0.4473684210526316, 0.0>
#   Vector3<0.42105263157894735, 0.42105263157894735, 0.0>
#   Vector3<0.39473684210526316, 0.39473684210526316, 0.0>
#   Vector3<0.368421052631579, 0.368421052631579, 0.0>
#   Vector3<0.34210526315789475, 0.34210526315789475, 0.0>
#   Vector3<0.3157894736842105, 0.3157894736842105, 0.0>
#   Vector3<0.2894736842105263, 0.2894736842105263, 0.0>
#   Vector3<0.26315789473684215, 0.26315789473684215, 0.0>
#   Vector3<0.2368421052631579, 0.2368421052631579, 0.0>
#   Vector3<0.21052631578947367, 0.21052631578947367, 0.0>
#   Vector3<0.1842105263157895, 0.1842105263157895, 0.0>
#   Vector3<0.1578947368421053, 0.1578947368421053, 0.0>
#   Vector3<0.13157894736842107, 0.13157894736842107, 0.0>
#   Vector3<0.10526315789473684, 0.10526315789473684, 0.0>
#   Vector3<0.07894736842105265, 0.07894736842105265, 0.0>
#   Vector3<0.052631578947368474, 0.052631578947368474, 0.0>
#   Vector3<0.026315789473684237, 0.026315789473684237, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.01287984848022461
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     iteration    1: trace = 14.57517592749192 (194.943% change)
#     iteration    2: trace = 5.564168044521661 (89.4866% change)
#     iteration    3: trace = 5.001717007900741 (10.6465% change)
#     iteration    4: trace = 4.761656049271242 (4.91758% change)
#     iteration    5: trace = 4.688645031439656 (1.54516% change)
#     iteration    6: trace = 4.673779037668683 (0.317567% change)
#     iteration    7: trace = 4.668019435652472 (0.123308% change)
#     iteration    8: trace = 4.666309360152599 (0.0366406% change)
#     iteration    9: trace = 4.666005582776086 (0.00651023% change)
#     iteration   10: trace = 4.665855758060893 (0.00321104% change)
#     iteration   11: trace = 4.665795495622445 (0.00129157% change)
#     iteration   12: trace = 4.665778006570618 (0.000374836% change)
#     iteration   13: trace = 4.665773473376349 (9.71584e-05% change)
#     iteration   14: trace = 4.665772927241036 (1.17051e-05% change)
#     iteration   15: trace = 4.665772784973086 (3.04918e-06% change)
# Finished solving for bands 2 to 8 after 15 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.613709, 0.627741, 0.627741, 0.657833, 0.965641, 0.991192, 1.07394
# elapsed time for k point: 0.046144723892211914
# solve_kpoint (0.0263158,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.665319485719392 (0.0705115% change)
#     iteration    2: trace = 4.663576592422142 (0.0373655% change)
#     iteration    3: trace = 4.663237680196696 (0.00726748% change)
#     iteration    4: trace = 4.663170798583908 (0.00143424% change)
#     iteration    5: trace = 4.663157934460028 (0.000275867% change)
#     iteration    6: trace = 4.663156446353609 (3.1912e-05% change)
#     iteration    7: trace = 4.663156037464587 (8.7685e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 2, 0.0263158, 0, 0, 0.0263158, 0.0174811, 0.608227, 0.627837, 0.629561, 0.661568, 0.964869, 0.989235, 1.07478
# elapsed time for k point: 0.0224609375
# solve_kpoint (0.0526316,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.657995672305782 (0.0629483% change)
#     iteration    2: trace = 4.656627128833067 (0.0293848% change)
#     iteration    3: trace = 4.656377657727359 (0.00535748% change)
#     iteration    4: trace = 4.656331415244372 (0.000993105% change)
#     iteration    5: trace = 4.656321557134868 (0.000211714% change)
#     iteration    6: trace = 4.656319408208129 (4.61507e-05% change)
#     iteration    7: trace = 4.656316882121759 (5.42507e-05% change)
#     iteration    8: trace = 4.656313214377805 (7.87692e-05% change)
#     iteration    9: trace = 4.656308035432851 (0.000111224% change)
#     iteration   10: trace = 4.656302385580932 (0.000121338% change)
#     iteration   11: trace = 4.656295384780082 (0.000150351% change)
#     iteration   12: trace = 4.656285457359619 (0.000213204% change)
#     iteration   13: trace = 4.656282047638567 (7.32284e-05% change)
#     iteration   14: trace = 4.656281435896867 (1.3138e-05% change)
#     iteration   15: trace = 4.65628118280045 (5.43559e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tmfreqs:, 3, 0.0526316, 0, 0, 0.0526316, 0.0349521, 0.597108, 0.628122, 0.631683, 0.670786, 0.962637, 0.983882, 1.07718
# elapsed time for k point: 0.040625810623168945
# solve_kpoint (0.0789474,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.64843286030184 (0.0515693% change)
#     iteration    2: trace = 4.647506824767085 (0.0199234% change)
#     iteration    3: trace = 4.647349938435378 (0.00337577% change)
#     iteration    4: trace = 4.647323236998091 (0.000574554% change)
#     iteration    5: trace = 4.647317235405791 (0.000129141% change)
#     iteration    6: trace = 4.647316262166402 (2.0942e-05% change)
#     iteration    7: trace = 4.647316000700248 (5.62618e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 4, 0.0789474, 0, 0, 0.0789474, 0.0524026, 0.584127, 0.628592, 0.633242, 0.68257, 0.959168, 0.976211, 1.0809
# elapsed time for k point: 0.0230863094329834
# solve_kpoint (0.105263,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.638835395377821 (0.0418644% change)
#     iteration    2: trace = 4.638212102045947 (0.0134373% change)
#     iteration    3: trace = 4.638106448948866 (0.00227791% change)
#     iteration    4: trace = 4.638084177881841 (0.000480177% change)
#     iteration    5: trace = 4.638076986868338 (0.000155043% change)
#     iteration    6: trace = 4.638075298268466 (3.64073e-05% change)
#     iteration    7: trace = 4.638074879705775 (9.02449e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 5, 0.105263, 0, 0, 0.105263, 0.0698219, 0.570328, 0.629235, 0.634678, 0.695427, 0.954746, 0.967192, 1.08561
# elapsed time for k point: 0.024763822555541992
# solve_kpoint (0.131579,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.630278141729415 (0.0354424% change)
#     iteration    2: trace = 4.629815978997286 (0.00998182% change)
#     iteration    3: trace = 4.629724441883805 (0.00197714% change)
#     iteration    4: trace = 4.629693716337425 (0.00066366% change)
#     iteration    5: trace = 4.629682838078036 (0.000234967% change)
#     iteration    6: trace = 4.629681000272839 (3.96961e-05% change)
#     iteration    7: trace = 4.629680691367955 (6.67227e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 6, 0.131579, 0, 0, 0.131579, 0.0871983, 0.556082, 0.630039, 0.636207, 0.708756, 0.949659, 0.957491, 1.09095
# elapsed time for k point: 0.022433042526245117
# solve_kpoint (0.157895,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.623249414346532 (0.0315777% change)
#     iteration    2: trace = 4.622855808381355 (0.00851398% change)
#     iteration    3: trace = 4.622749899933901 (0.002291% change)
#     iteration    4: trace = 4.622702307931009 (0.00102952% change)
#     iteration    5: trace = 4.622690159505014 (0.0002628% change)
#     iteration    6: trace = 4.62268888501997 (2.75702e-05% change)
#     iteration    7: trace = 4.622688720602637 (3.55675e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 7, 0.157895, 0, 0, 0.157895, 0.104519, 0.541556, 0.630985, 0.637901, 0.722306, 0.944159, 0.947528, 1.09656
# elapsed time for k point: 0.02516007423400879
# solve_kpoint (0.184211,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.617891516334212 (0.0293454% change)
#     iteration    2: trace = 4.617512231060463 (0.00821372% change)
#     iteration    3: trace = 4.617371662859377 (0.00304429% change)
#     iteration    4: trace = 4.617309427780985 (0.00134786% change)
#     iteration    5: trace = 4.617298935918713 (0.000227229% change)
#     iteration    6: trace = 4.617298171812583 (1.65488e-05% change)
#     iteration    7: trace = 4.617298071787932 (2.1663e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 8, 0.184211, 0, 0, 0.184211, 0.12177, 0.526834, 0.632053, 0.639774, 0.735956, 0.93758, 0.938457, 1.10215
# elapsed time for k point: 0.025089740753173828
# solve_kpoint (0.210526,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.614172431132557 (0.0280389% change)
#     iteration    2: trace = 4.613779879595334 (0.00850788% change)
#     iteration    3: trace = 4.613598011765511 (0.00394192% change)
#     iteration    4: trace = 4.613529590376666 (0.00148305% change)
#     iteration    5: trace = 4.61352065075385 (0.00019377% change)
#     iteration    6: trace = 4.613517984852372 (5.77846e-05% change)
#     near maximum in trace
#     iteration    7: trace = 4.583609596183774 (0.650385% change)
#     iteration    8: trace = 4.583601333364053 (0.000180269% change)
#     iteration    9: trace = 4.583592974590865 (0.000182363% change)
#     iteration   10: trace = 4.583584519115127 (0.000184473% change)
#     iteration   11: trace = 4.583575966055728 (0.000186602% change)
#     iteration   12: trace = 4.583567314395992 (0.000188754% change)
#     iteration   13: trace = 4.583558562979552 (0.00019093% change)
#     iteration   14: trace = 4.583549710506267 (0.000193136% change)
#     iteration   15: trace = 4.583540755528184 (0.000195372% change)
#     iteration   16: trace = 4.583531696445452 (0.000197644% change)
#     iteration   17: trace = 4.583522531502159 (0.000199954% change)
#     iteration   18: trace = 4.583513258781994 (0.000202306% change)
#     iteration   19: trace = 4.583503876203785 (0.000204703% change)
#     iteration   20: trace = 4.583494381516739 (0.000207149% change)
#     iteration   21: trace = 4.583484772295448 (0.000209649% change)
#     iteration   22: trace = 4.583475045934502 (0.000212205% change)
#     iteration   23: trace = 4.583465199642764 (0.000214822% change)
#     iteration   24: trace = 4.583455230437169 (0.000217504% change)
#     iteration   25: trace = 4.583445135136034 (0.000220256% change)
#     iteration   26: trace = 4.583434910351837 (0.000223081% change)
#     iteration   27: trace = 4.583424552483365 (0.000225985% change)
#     iteration   28: trace = 4.583414057707208 (0.000228973% change)
#     iteration   29: trace = 4.583403421968526 (0.000232049% change)
#     iteration   30: trace = 4.583392640971021 (0.000235218% change)
#     iteration   31: trace = 4.583381710166035 (0.000238487% change)
#     iteration   32: trace = 4.583370624740734 (0.000241862% change)
#     iteration   33: trace = 4.58335937960524 (0.000245347% change)
#     iteration   34: trace = 4.583347969376264 (0.000248949% change)
#     iteration   35: trace = 4.583336388368465 (0.000252676% change)
#     iteration   36: trace = 4.583324630572111 (0.000256534% change)
#     iteration   37: trace = 4.583312689636986 (0.00026053% change)
#     iteration   38: trace = 4.583300558853002 (0.000264673% change)
#     iteration   39: trace = 4.583288231129109 (0.000268971% change)
#     iteration   40: trace = 4.583275698970464 (0.000273432% change)
#     iteration   41: trace = 4.583262954453588 (0.000278066% change)
#     iteration   42: trace = 4.5832499891994 (0.000282883% change)
#     iteration   43: trace = 4.583236794343943 (0.000287893% change)
#     iteration   44: trace = 4.583223360506582 (0.000293109% change)
#     iteration   45: trace = 4.583209677755443 (0.00029854% change)
#     iteration   46: trace = 4.583195735569876 (0.000304202% change)
#     iteration   47: trace = 4.583181522799639 (0.000310107% change)
#     iteration   48: trace = 4.583167027620556 (0.000316269% change)
#     iteration   49: trace = 4.583152237486307 (0.000322706% change)
#     iteration   50: trace = 4.583137139076011 (0.000329433% change)
#     iteration   51: trace = 4.583121718237248 (0.00033647% change)
#     iteration   52: trace = 4.583105959924139 (0.000343834% change)
#     iteration   53: trace = 4.583089848130045 (0.000351548% change)
#     iteration   54: trace = 4.583073365814466 (0.000359634% change)
#     iteration   55: trace = 4.583056494823703 (0.000368116% change)
#     iteration   56: trace = 4.583039215804793 (0.00037702% change)
#     iteration   57: trace = 4.583021508112282 (0.000386375% change)
#     iteration   58: trace = 4.583003349707423 (0.000396211% change)
#     iteration   59: trace = 4.582984717049372 (0.000406561% change)
#     iteration   60: trace = 4.582965584978114 (0.00041746% change)
#     iteration   61: trace = 4.582945926588897 (0.000428946% change)
#     iteration   62: trace = 4.582925713098277 (0.00044106% change)
#     iteration   63: trace = 4.582904913701965 (0.000453846% change)
#     iteration   64: trace = 4.582883495425264 (0.000467353% change)
#     iteration   65: trace = 4.582861422967337 (0.000481629% change)
#     iteration   66: trace = 4.582838658541339 (0.000496731% change)
#     iteration   67: trace = 4.582815161713538 (0.000512715% change)
#     iteration   68: trace = 4.582790889245936 (0.000529642% change)
#     iteration   69: trace = 4.582765794948873 (0.000547578% change)
#     resetting CG direction...
#     large trace change predicted (1.89795%)
#     iteration   70: trace = 4.493769319242049 (1.96102% change)
#     iteration   71: trace = 4.480494008150559 (0.295853% change)
#     iteration   72: trace = 4.476301383614778 (0.0936189% change)
#     iteration   73: trace = 4.473811718326718 (0.0556343% change)
#     iteration   74: trace = 4.473311997106084 (0.0111705% change)
#     iteration   75: trace = 4.473242850544986 (0.00154577% change)
#     iteration   76: trace = 4.473230107773226 (0.000284867% change)
#     iteration   77: trace = 4.473227464541976 (5.909e-05% change)
#     iteration   78: trace = 4.473227234692271 (5.13834e-06% change)
# Finished solving for bands 1 to 8 after 78 iterations.
# tmfreqs:, 9, 0.210526, 0, 0, 0.210526, 0.138934, 0.51197, 0.633217, 0.641809, 0.749645, 0.927837, 0.932721, 1.04217
# elapsed time for k point: 0.18944048881530762
# solve_kpoint (0.236842,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.435141913346344 (0.026126% change)
#     iteration    2: trace = 4.434880490500386 (0.00589453% change)
#     iteration    3: trace = 4.434842397252827 (0.00085895% change)
#     iteration    4: trace = 4.434835586865919 (0.000153566% change)
#     iteration    5: trace = 4.434834579174507 (2.27222e-05% change)
#     iteration    6: trace = 4.434834481565487 (2.20096e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 10, 0.236842, 0, 0, 0.236842, 0.15599, 0.497003, 0.63445, 0.643978, 0.763337, 0.918445, 0.92709, 1.02982
# elapsed time for k point: 0.024096250534057617
# solve_kpoint (0.263158,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.399391023940742 (0.0226125% change)
#     iteration    2: trace = 4.399213289907924 (0.00404005% change)
#     iteration    3: trace = 4.399190546686955 (0.000516985% change)
#     iteration    4: trace = 4.399186933515301 (8.21327e-05% change)
#     iteration    5: trace = 4.399186431138357 (1.14198e-05% change)
#     iteration    6: trace = 4.399186375744326 (1.25919e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 11, 0.263158, 0, 0, 0.263158, 0.172911, 0.481968, 0.635719, 0.646238, 0.777012, 0.909524, 0.921679, 1.01723
# elapsed time for k point: 0.02002692222595215
# solve_kpoint (0.289474,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.366829295346278 (0.0201923% change)
#     iteration    2: trace = 4.366702072034412 (0.00291344% change)
#     iteration    3: trace = 4.366687565589928 (0.000332207% change)
#     iteration    4: trace = 4.36668543280682 (4.88421e-05% change)
#     iteration    5: trace = 4.3666851601005 (6.24516e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 12, 0.289474, 0, 0, 0.289474, 0.189663, 0.466907, 0.636991, 0.648539, 0.790654, 0.901182, 0.916584, 1.00447
# elapsed time for k point: 0.016901731491088867
# solve_kpoint (0.315789,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.337707328073009 (0.0184675% change)
#     iteration    2: trace = 4.337612155388798 (0.0021941% change)
#     iteration    3: trace = 4.337602401483807 (0.000224868% change)
#     iteration    4: trace = 4.337601028005722 (3.16645e-05% change)
#     iteration    5: trace = 4.337600872020214 (3.59612e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 13, 0.315789, 0, 0, 0.315789, 0.206192, 0.451872, 0.638232, 0.650819, 0.804247, 0.893525, 0.911888, 0.99159
# elapsed time for k point: 0.020264387130737305
# solve_kpoint (0.342105,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.312204350653936 (0.0172022% change)
#     iteration    2: trace = 4.312130375954382 (0.00171549% change)
#     iteration    3: trace = 4.312123590112109 (0.000157366% change)
#     iteration    4: trace = 4.312122668359588 (2.13758e-05% change)
#     iteration    5: trace = 4.312122577891262 (2.098e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 14, 0.342105, 0, 0, 0.342105, 0.222423, 0.436939, 0.639403, 0.653012, 0.817775, 0.886662, 0.907664, 0.978619
# elapsed time for k point: 0.020918846130371094
# solve_kpoint (0.368421,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.290451196946109 (0.0162636% change)
#     iteration    2: trace = 4.290391544598356 (0.00139036% change)
#     iteration    3: trace = 4.290386652478727 (0.000114025% change)
#     iteration    4: trace = 4.290386013428181 (1.48949e-05% change)
#     iteration    5: trace = 4.290385959761879 (1.25085e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 15, 0.368421, 0, 0, 0.368421, 0.238232, 0.422233, 0.64047, 0.655046, 0.831198, 0.880717, 0.903976, 0.965577
# elapsed time for k point: 0.020750761032104492
# solve_kpoint (0.394737,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.272543601809115 (0.0155645% change)
#     iteration    2: trace = 4.272493746966701 (0.00116687% change)
#     iteration    3: trace = 4.272490087314291 (8.56562e-05% change)
#     iteration    4: trace = 4.272489633504371 (1.06217e-05% change)
#     iteration    5: trace = 4.272489600759378 (7.66415e-07% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 16, 0.394737, 0, 0, 0.394737, 0.253403, 0.407966, 0.641397, 0.656845, 0.844409, 0.875888, 0.900879, 0.952479
# elapsed time for k point: 0.020734786987304688
# solve_kpoint (0.421053,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.258551334448844 (0.0150493% change)
#     iteration    2: trace = 4.258508154989554 (0.00101395% change)
#     iteration    3: trace = 4.258505297638963 (6.70975e-05% change)
#     iteration    4: trace = 4.258504966943061 (7.76554e-06% change)
# Finished solving for bands 1 to 8 after 4 iterations.
# tmfreqs:, 17, 0.421053, 0, 0, 0.421053, 0.26754, 0.394533, 0.642155, 0.658339, 0.856866, 0.872791, 0.898419, 0.939339
# elapsed time for k point: 0.017398357391357422
# solve_kpoint (0.447368,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.248524019388966 (0.0146829% change)
#     iteration    2: trace = 4.248485245562695 (0.000912646% change)
#     iteration    3: trace = 4.248482864596227 (5.60427e-05% change)
#     iteration    4: trace = 4.248482610560172 (5.97945e-06% change)
# Finished solving for bands 1 to 8 after 4 iterations.
# tmfreqs:, 18, 0.447368, 0, 0, 0.447368, 0.279867, 0.382711, 0.642716, 0.65946, 0.864391, 0.875668, 0.896634, 0.926175
# elapsed time for k point: 0.018717050552368164
# solve_kpoint (0.473684,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.242494696952449 (0.0144382% change)
#     iteration    2: trace = 4.242458601835933 (0.000850803% change)
#     iteration    3: trace = 4.2424565229132 (4.90028e-05% change)
#     iteration    4: trace = 4.242456316257416 (4.87114e-06% change)
# Finished solving for bands 1 to 8 after 4 iterations.
# tmfreqs:, 19, 0.473684, 0, 0, 0.473684, 0.288883, 0.373997, 0.643061, 0.660155, 0.864612, 0.886915, 0.895552, 0.913023
# elapsed time for k point: 0.015873193740844727
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.240482457458691 (0.0143038% change)
#     iteration    2: trace = 4.240447591600574 (0.000822218% change)
#     iteration    3: trace = 4.240445637461834 (4.60833e-05% change)
#     iteration    4: trace = 4.240445449326632 (4.43668e-06% change)
# Finished solving for bands 1 to 8 after 4 iterations.
# tmfreqs:, 20, 0.5, 0, 0, 0.5, 0.292334, 0.370648, 0.643178, 0.660391, 0.864297, 0.895189, 0.898672, 0.901015
# elapsed time for k point: 0.01848602294921875
# solve_kpoint (0.5,0.0263158,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.242005344744754 (0.0261945% change)
#     iteration    2: trace = 4.241921159094765 (0.00198459% change)
#     iteration    3: trace = 4.241916734726153 (0.000104301% change)
#     iteration    4: trace = 4.241916178268763 (1.31181e-05% change)
#     iteration    5: trace = 4.241916151956253 (6.20298e-07% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 21, 0.5, 0.0263158, 0, 0.500692, 0.29272, 0.371098, 0.636537, 0.667059, 0.857849, 0.898682, 0.901041, 0.901643
# elapsed time for k point: 0.02149224281311035
# solve_kpoint (0.5,0.0526316,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.246410472719354 (0.0262979% change)
#     iteration    2: trace = 4.246322893187179 (0.00206246% change)
#     iteration    3: trace = 4.24631804018572 (0.000114287% change)
#     iteration    4: trace = 4.246317445823444 (1.39971e-05% change)
#     iteration    5: trace = 4.246317410421804 (8.33702e-07% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 22, 0.5, 0.0526316, 0, 0.502762, 0.293874, 0.372442, 0.625216, 0.678463, 0.845104, 0.898759, 0.901119, 0.914358
# elapsed time for k point: 0.027179479598999023
# solve_kpoint (0.5,0.0789474,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.253716766203598 (0.026564% change)
#     iteration    2: trace = 4.253622607185511 (0.00221359% change)
#     iteration    3: trace = 4.253616965699631 (0.000132628% change)
#     iteration    4: trace = 4.253616293608382 (1.58005e-05% change)
#     iteration    5: trace = 4.253616242131361 (1.21019e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 23, 0.5, 0.0789474, 0, 0.506194, 0.295784, 0.37466, 0.613178, 0.690641, 0.830814, 0.898876, 0.901247, 0.928606
# elapsed time for k point: 0.028959035873413086
# solve_kpoint (0.5,0.105263,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.263868432355255 (0.0269966% change)
#     iteration    2: trace = 4.263764137106264 (0.00244605% change)
#     iteration    3: trace = 4.263757271959246 (0.000161012% change)
#     iteration    4: trace = 4.263756467278933 (1.88726e-05% change)
#     iteration    5: trace = 4.263756391703042 (1.77252e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 24, 0.5, 0.105263, 0, 0.51096, 0.29843, 0.377718, 0.600979, 0.703036, 0.816098, 0.899036, 0.90142, 0.943266
# elapsed time for k point: 0.022334814071655273
# solve_kpoint (0.5,0.131579,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.276784609782856 (0.0276025% change)
#     iteration    2: trace = 4.276666023721285 (0.00277282% change)
#     iteration    3: trace = 4.276657371385317 (0.000202315% change)
#     iteration    4: trace = 4.276656353962695 (2.37901e-05% change)
#     iteration    5: trace = 4.276656244517024 (2.55914e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 25, 0.5, 0.131579, 0, 0.517023, 0.301785, 0.381571, 0.588766, 0.715507, 0.801297, 0.899233, 0.901633, 0.957992
# elapsed time for k point: 0.022418737411499023
# solve_kpoint (0.5,0.157895,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.292356271706423 (0.0283927% change)
#     iteration    2: trace = 4.292218357364449 (0.00321307% change)
#     iteration    3: trace = 4.292207146008058 (0.000261202% change)
#     iteration    4: trace = 4.292205796018873 (3.14521e-05% change)
#     iteration    5: trace = 4.292205639794743 (3.63972e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 26, 0.5, 0.157895, 0, 0.524338, 0.305816, 0.38616, 0.576601, 0.727994, 0.786573, 0.899464, 0.90188, 0.972625
# elapsed time for k point: 0.01837468147277832
# solve_kpoint (0.5,0.184211,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.310441751413268 (0.0293834% change)
#     iteration    2: trace = 4.310278213997313 (0.00379405% change)
#     iteration    3: trace = 4.310263346677615 (0.000344928% change)
#     iteration    4: trace = 4.310261484889486 (4.31943e-05% change)
#     iteration    5: trace = 4.310261263186837 (5.1436e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 27, 0.5, 0.184211, 0, 0.532854, 0.31048, 0.391413, 0.564522, 0.74046, 0.772029, 0.899723, 0.902152, 0.987058
# elapsed time for k point: 0.019277095794677734
# solve_kpoint (0.5,0.210526,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.330860453733253 (0.0305976% change)
#     iteration    2: trace = 4.33066323692344 (0.00455386% change)
#     iteration    3: trace = 4.330643122176379 (0.000464474% change)
#     iteration    4: trace = 4.330640483089403 (6.09399e-05% change)
#     iteration    5: trace = 4.330640166426861 (7.31214e-06% change)
# Finished solving for bands 1 to 8 after 5 iterations.
# tmfreqs:, 28, 0.5, 0.210526, 0, 0.542514, 0.315732, 0.397245, 0.552564, 0.752878, 0.757755, 0.900002, 0.90244, 1.0012
# elapsed time for k point: 0.0243070125579834
# solve_kpoint (0.5,0.236842,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.353384140171727 (0.0320666% change)
#     iteration    2: trace = 4.353142739606872 (0.00554528% change)
#     iteration    3: trace = 4.353115048785694 (0.000636113% change)
#     iteration    4: trace = 4.353111243568947 (8.74137e-05% change)
#     iteration    5: trace = 4.353110782106526 (1.06008e-05% change)
#     iteration    6: trace = 4.353110695147548 (1.99763e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 29, 0.5, 0.236842, 0, 0.553258, 0.321517, 0.403555, 0.540761, 0.743839, 0.765216, 0.900295, 0.902732, 1.01496
# elapsed time for k point: 0.02540111541748047
# solve_kpoint (0.5,0.263158,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.377724900266307 (0.0338344% change)
#     iteration    2: trace = 4.377425266223401 (0.00684475% change)
#     iteration    3: trace = 4.377386767127088 (0.000879496% change)
#     iteration    4: trace = 4.377381265092911 (0.000125692% change)
#     iteration    5: trace = 4.377380575739497 (1.57481e-05% change)
#     iteration    6: trace = 4.37738041577567 (3.65433e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 30, 0.5, 0.263158, 0, 0.565024, 0.327771, 0.410228, 0.529153, 0.73038, 0.777441, 0.900593, 0.903015, 1.02824
# elapsed time for k point: 0.016439199447631836
# solve_kpoint (0.5,0.289474,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.40351890841855 (0.0359539% change)
#     iteration    2: trace = 4.403142599746403 (0.008546% change)
#     iteration    3: trace = 4.403088330312705 (0.00123252% change)
#     iteration    4: trace = 4.403080293723954 (0.000182522% change)
#     iteration    5: trace = 4.403079206304605 (2.46968e-05% change)
#     iteration    6: trace = 4.403078906564241 (6.80752e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 31, 0.5, 0.289474, 0, 0.57775, 0.334421, 0.417127, 0.517791, 0.717491, 0.789508, 0.900889, 0.903272, 1.04092
# elapsed time for k point: 0.021327495574951172
# solve_kpoint (0.5,0.315789,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.430304196540398 (0.0384993% change)
#     iteration    2: trace = 4.429826346290642 (0.0107865% change)
#     iteration    3: trace = 4.429749342187924 (0.00173832% change)
#     iteration    4: trace = 4.429737553495087 (0.000266126% change)
#     iteration    5: trace = 4.429735729689099 (4.11719e-05% change)
#     iteration    6: trace = 4.429735155863614 (1.29539e-05% change)
#     iteration    7: trace = 4.429735094796865 (1.37856e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 32, 0.5, 0.315789, 0, 0.591374, 0.341377, 0.424091, 0.50674, 0.70531, 0.801355, 0.901173, 0.903487, 1.05286
# elapsed time for k point: 0.025381088256835938
# solve_kpoint (0.5,0.342105,0):
# Solving for bands 1 to 8...
#     iteration    1: trace = 4.457490897137283 (0.0415642% change)
#     iteration    2: trace = 4.456878048326501 (0.0137497% change)
#     iteration    3: trace = 4.456768533831852 (0.00245723% change)
#     iteration    4: trace = 4.456751262473202 (0.000387532% change)
#     iteration    5: trace = 4.456747987527438 (7.34828e-05% change)
#     iteration    6: trace = 4.456746868136443 (2.51168e-05% change)
#     iteration    7: trace = 4.456746745544113 (2.75071e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 33, 0.5, 0.342105, 0, 0.605835, 0.348522, 0.430933, 0.496095, 0.694002, 0.812892, 0.901439, 0.903634, 1.0639
# elapsed time for k point: 0.02443075180053711
# solve_kpoint (0.5,0.368421,0):
# Solving for bands 1 to 8...
# ...
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     656 """Write to current stream after encoding if necessary
#     657
#     658 Returns
#    (...)    662
#     663 """
# --> 664 parent = self.parent_header
#     666 if not isinstance(string, str):
#
# SystemError: <function OutStream.parent_header at 0x78a770de6d40> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[12], line 74
#      72 for reg in ["AA", "AB", "BA"]:
#      73     outp = os.path.join(output_dir, f"08_final_bands_{reg}_1x")
# ---> 74     png = run_bands_for_cell(reg, L1_opt, L2_opt, cand.lattice_type, cand.band_index, cand.k_label, outp)
#      75     final_band_plots.append(png)
#      77 final_band_plots
#
# Cell In[9], line 41, in run_bands_for_cell(registry, l1, l2, lattice_type, target_band, k_label, out_prefix)
#      39 result = {}
#      40 if pol == "tm":
# ---> 41     ms.run_tm(); result["freqs"] = np.array(ms.all_freqs)
#      42 elif pol == "te":
#      43     ms.run_te(); result["freqs"] = np.array(ms.all_freqs)
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/meep/mpb/solver.py:978, in ModeSolver.run_zodd(self, *band_functions)
#     977 def run_zodd(self, *band_functions):
# --> 978     self.run_parity(mp.ODD_Z, True, *band_functions)
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/meep/mpb/solver.py:929, in ModeSolver.run_parity(self, p, reset_fields, *band_functions)
#     927 self.current_k = k
#     928 solve_kpoint_time = time.time()
# --> 929 self.solve_kpoint(k)
#     930 self.iterations = self.mode_solver.get_iterations()
#     931 if verbosity.mpb > 0:
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/meep/mpb/solver.py:889, in ModeSolver.solve_kpoint(self, k)
#     888 def solve_kpoint(self, k):
# --> 889     self.mode_solver.solve_kpoint(k)
#     890     self.freqs = self.get_freqs()
#
# File ~/.local/share/mamba/envs/msl/lib/python3.11/site-packages/meep/mpb/__init__.py:124, in mode_solver.solve_kpoint(self, kpoint)
#     123 def solve_kpoint(self, kpoint):
# --> 124     return _mpb.mode_solver_solve_kpoint(self, kpoint)
#
# SystemError: <built-in function mode_solver_solve_kpoint> returned a result with an exception set

# %% [markdown]
# ## Reciprocal-space unit-cell approximation (registry-based)
#
# We switch to reciprocal space for registry visualization and basis selection, per your spec:
# - Use the reciprocal unit cell of lattice 1 (or a scaled rectangle enclosing its reciprocal cell for mini-BZ variants).
# - Query reciprocal lattice points of lattice 2 within that rectangle using the Python binding `get_reciprocal_lattice_points_in_rectangle`.
# - Fold those points into lattice 1's reciprocal cell and treat the non-integer sites as “strays.”
# - Define the MPB real-space basis as: one lattice-1 site at (0,0) plus one additional site per stray (usually one for factor=1). The number of strays scales with the mini-BZ factor.
#
# Notes:
# - All registry/stacking visualizations below are in reciprocal space.
# - Geometry in MPB remains a real-space lattice; we only use the reciprocal stray count to determine how many basis sites to include. If you prefer a different mapping from reciprocal strays to real-space offsets, say so and we will change it.
#
# Usage (expects Python bindings objects):
# - `L1_py = moire.lattice_1()` and `L2_py = moire.lattice_2()` from a built `PyMoire2D`.
# - Call plotting and basis helpers below with `L1_py`, `L2_py`, and `factor` (1 for mini-bz 1, 2 for mini-bz 2, ...).

# %%
# Visualize envelope potential and ground state at the optimal angle
N_vis = 96
U, V, Vgrid, _ = build_moire_potential(opt_theta, edges, omega0, N=N_vis)
lam0_opt, F0 = solve_envelope(Vgrid, alpha)
print(f"Optimal envelope ground-state λ0 = {lam0_opt:.6f}")

# Normalize F0 for plotting
F0_abs = np.abs(F0)
F0_abs /= (F0_abs.max() + 1e-12)

plt.figure(figsize=(5,4))
plt.imshow(Vgrid.T, origin='lower', extent=[0,1,0,1], cmap='viridis', aspect='equal')
plt.colorbar(label='V (ω units)')
plt.title('Moiré potential V(u,v) at optimal angle')
plt.tight_layout(); plt.savefig(os.path.join(output_dir, '06_potential_optimal.png'), dpi=160); plt.close()

plt.figure(figsize=(5,4))
plt.imshow(F0_abs.T, origin='lower', extent=[0,1,0,1], cmap='magma', aspect='equal')
plt.colorbar(label='|F| (normed)')
plt.title('Envelope ground-state |F(u,v)| at optimal angle')
plt.tight_layout(); plt.savefig(os.path.join(output_dir, '06_envelope_groundstate_optimal.png'), dpi=160); plt.close()
